# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

from loadData import DataLoader

# %% [markdown]
# # Load data

# %%
path = '../data-sets/KDD-Cup/data/'

loader = DataLoader(path)

data_df_list = loader.getDataInDfList()
# Out:
# ..........................................................................................................................................................................................................................................................

# %%
name, data_df = data_df_list[33]

df_train = data_df[data_df['label']=='train']['values'].to_frame()
df_test = data_df[data_df['label']=='test']['values'].to_frame()

print(name)
print('df_train.shape =', df_train.shape)
print('df_test.shape =', df_test.shape)
# Out:
# 034_UCR_Anomaly_1500.txt
# df_train.shape = (1500, 1)
# df_test.shape = (6154, 1)

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Plot of training data (without anomaly)

# %%
N, M = 30, 6
fig, ax = plt.subplots(figsize=(N, M))
df_train.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ## Plot of testing data (with anomaly)

# %%
N, M = 30, 6
fig, ax = plt.subplots(figsize=(N, M))
df_test.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# # Prepare training data
#
# ## Normalization

# %%
# Normalize and save the mean and std we get,
# for normalizing test data.
training_mean = df_train.mean()
training_std = df_train.std()
df_training_value = (df_train - training_mean) / training_std

print("Number of training samples:", len(df_training_value))

display(df_train)

df_training_value
# Out:
# Number of training samples: 1500
#          values
# 0     76.458008
# 1     76.362195
# 2     77.233139
# 3     77.797305
# 4     77.612248
# ...         ...
# 1495  52.184675
# 1496  54.806667
# 1497  56.179042
# 1498  57.921033
# 1499  59.442607
#
# [1500 rows x 1 columns]
#         values
# 0     1.215527
# 1     1.207374
# 2     1.281481
# 3     1.329485
# 4     1.313739
# ...        ...
# 1495 -0.849837
# 1496 -0.626737
# 1497 -0.509965
# 1498 -0.361743
# 1499 -0.232276
#
# [1500 rows x 1 columns]

# %%
display(df_train.describe())

df_training_value.describe()
# Out:
#             values
# count  1500.000000
# mean     62.172443
# std      11.752570
# min      45.275126
# 25%      51.324798
# 50%      59.914537
# 75%      72.048791
# max      89.698638
#              values
# count  1.500000e+03
# mean  -1.136868e-16
# std    1.000000e+00
# min   -1.437755e+00
# 25%   -9.230019e-01
# 50%   -1.921202e-01
# 75%    8.403565e-01
# max    2.342143e+00

# %% [markdown]
# ## Discretize the Time series data by sliding window

# %%
TIME_STEPS = 150 #288

# Generated training sequences for use in the model.

def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
x_train
# Out:
# Training input shape:  (1351, 150, 1)
# array([[[ 1.21552695],
#         [ 1.20737443],
#         [ 1.28148112],
#         ...,
#         [ 1.33455385],
#         [ 1.37429061],
#         [ 1.37489975]],
#
#        [[ 1.20737443],
#         [ 1.28148112],
#         [ 1.32948475],
#         ...,
#         [ 1.37429061],
#         [ 1.37489975],
#         [ 1.34518412]],
#
#        [[ 1.28148112],
#         [ 1.32948475],
#         [ 1.31373866],
#         ...,
#         [ 1.37489975],
#         [ 1.34518412],
#         [ 1.40551544]],
#
#        ...,
#
#        [[ 0.89142574],
#         [ 0.96399302],
#         [ 1.1024584 ],
#         ...,
#         [-0.84983693],
#         [-0.62673747],
#         [-0.50996514]],
#
#        [[ 0.96399302],
#         [ 1.1024584 ],
#         [ 1.18931115],
#         ...,
#         [-0.62673747],
#         [-0.50996514],
#         [-0.361743  ]],
#
#        [[ 1.1024584 ],
#         [ 1.18931115],
#         [ 1.27769097],
#         ...,
#         [-0.50996514],
#         [-0.361743  ],
#         [-0.23227565]]])

# %% [markdown]
# ## Pad zeros in training data

# %% [markdown]
# ``` python
# a = np.arange(12)
# display(a)
#
# a = a.reshape((3, 4, 1))
# display(a)
#
# data1=np.pad(a, ((0,0), (0,2), (0, 0)), 'constant')
# display(data1.shape)
#
# data1
# ```

# %%
x_train_padded_zero = np.pad(x_train, ((0,0), (0,2), (0, 0)), 'constant')
x_train_padded_zero.shape
# Out:
# (1351, 152, 1)

# %% [markdown]
# # Build a model

# %%
x_train.shape[1], x_train.shape[2]
# Out:
# (150, 1)

# %%
model = keras.Sequential(
    [
        layers.Input(shape=(x_train_padded_zero.shape[1], x_train_padded_zero.shape[2])),
        layers.Conv1D(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1D(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(
            filters=16, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(
            filters=32, kernel_size=7, padding="same", strides=2, activation="relu"
        ),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 76, 32)            256
# _________________________________________________________________
# dropout (Dropout)            (None, 76, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 38, 16)            3600
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 76, 16)            1808
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 76, 16)            0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 152, 32)           3616
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 152, 1)            225
# =================================================================
# Total params: 9,505
# Trainable params: 9,505
# Non-trainable params: 0
# _________________________________________________________________
# 2021-11-02 00:05:50.212824: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Train model

# %%
history = model.fit(
    x_train_padded_zero,
    x_train_padded_zero,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")
    ],
)
# Out:
# 2021-11-02 00:05:50.782934: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 38/38 [==============================] - 2s 25ms/step - loss: 0.3305 - val_loss: 0.0485
# Epoch 2/50
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0493 - val_loss: 0.0264
# Epoch 3/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0337 - val_loss: 0.0170
# Epoch 4/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0257 - val_loss: 0.0179
# Epoch 5/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0212 - val_loss: 0.0127
# Epoch 6/50
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0177 - val_loss: 0.0130
# Epoch 7/50
# 38/38 [==============================] - 0s 13ms/step - loss: 0.0147 - val_loss: 0.0117
# Epoch 8/50
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0134 - val_loss: 0.0153
# Epoch 9/50
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0120 - val_loss: 0.0164
# Epoch 10/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0110 - val_loss: 0.0142
# Epoch 11/50
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0101 - val_loss: 0.0217
# Epoch 12/50
# 38/38 [==============================] - 1s 26ms/step - loss: 0.0094 - val_loss: 0.0209

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Detecting anomalies

# %%
# Get train MAE loss.
x_train_pred = model.predict(x_train_padded_zero)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train_padded_zero), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)
# Out:
# Reconstruction error threshold:  0.14059678961399202

# %% [markdown]
# ## Compare recontruction
#
# ### Test with training data

# %%
# Checking how the first sequence is learnt
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# # Test with testing data
#
# ##  Prepare test data and predict

# %%
df_test_value = (df_test - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)

# Padding zeros to meet autoencoder input-dimension 
x_test = np.pad(x_test, ((0,0), (0,2), (0, 0)), 'constant')
print("Padded zeros, Test input shape: ", x_test.shape)

# Get test MAE loss.
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Test input shape:  (6005, 150, 1)
# Padded zeros, Test input shape:  (6005, 152, 1)
# Number of anomaly samples:  107
# Indices of anomaly samples:  (array([1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946,
#        1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#        2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034,
#        2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042]),)

# %%
np.where(anomalies)
# Out:
# (array([1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946,
#         1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#         1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#         1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#         1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#         1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#         2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#         2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#         2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034,
#         2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042]),)

# %% [markdown]
# # Plot anomalies

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)

anomalous_data_indices
# Out:
# []

# %%
df_subset = df_test.iloc[anomalous_data_indices]
display(df_subset)
N, M = 30, 6
fig, ax = plt.subplots(figsize=(N, M))
df_test.plot(legend=False, ax=ax)
df_subset.plot(legend=False, ax=ax, color="r")
plt.show()
# Out:
# Empty DataFrame
# Columns: [values]
# Index: []
