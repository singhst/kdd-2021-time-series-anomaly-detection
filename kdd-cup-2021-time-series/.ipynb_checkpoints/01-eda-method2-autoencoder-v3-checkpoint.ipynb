# %% [markdown]
# Reference
#
# https://keras.io/examples/timeseries/timeseries_anomaly_detection/

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Define-Functions" data-toc-modified-id="Define-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Define Functions</a></span><ul class="toc-item"><li><span><a href="#Visualization" data-toc-modified-id="Visualization-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Visualization</a></span><ul class="toc-item"><li><span><a href="#def-plotTimeSeries()" data-toc-modified-id="def-plotTimeSeries()-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span><code>def plotTimeSeries()</code></a></span></li></ul></li><li><span><a href="#Find-window-size" data-toc-modified-id="Find-window-size-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Find window size</a></span><ul class="toc-item"><li><span><a href="#def-findDominantFreq():---Find-the-freq-with-strongest-strength-in-Periodogram" data-toc-modified-id="def-findDominantFreq():---Find-the-freq-with-strongest-strength-in-Periodogram-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span><code>def findDominantFreq():</code> - Find the freq with strongest strength in Periodogram</a></span></li><li><span><a href="#def-findAutoPeriod()---Find-the-period-of-the-time-series-data" data-toc-modified-id="def-findAutoPeriod()---Find-the-period-of-the-time-series-data-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span><code>def findAutoPeriod()</code> - Find the period of the time series data</a></span></li></ul></li><li><span><a href="#Prepare-Data" data-toc-modified-id="Prepare-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Prepare Data</a></span><ul class="toc-item"><li><span><a href="#def-normalize(df):" data-toc-modified-id="def-normalize(df):-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span><code>def normalize(df):</code></a></span></li></ul></li><li><span><a href="#Discretize-the-Time-series-data-by-sliding-window" data-toc-modified-id="Discretize-the-Time-series-data-by-sliding-window-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Discretize the Time series data by sliding window</a></span><ul class="toc-item"><li><span><a href="#def-createSequences(values,-time_steps=100):" data-toc-modified-id="def-createSequences(values,-time_steps=100):-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span><code>def createSequences(values, time_steps=100):</code></a></span></li></ul></li><li><span><a href="#Build,-Train-&amp;-Save-model" data-toc-modified-id="Build,-Train-&amp;-Save-model-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Build, Train &amp; Save model</a></span><ul class="toc-item"><li><span><a href="#def-buildAutoencoder(train_df,-model_name,-folder):" data-toc-modified-id="def-buildAutoencoder(train_df,-model_name,-folder):-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span><code>def buildAutoencoder(train_df, model_name, folder):</code></a></span></li><li><span><a href="#def-saveAutoencoder(model_name,-folder):" data-toc-modified-id="def-saveAutoencoder(model_name,-folder):-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span><code>def saveAutoencoder(model_name, folder):</code></a></span></li><li><span><a href="#def-trainAutoencoder(x_train,-model):" data-toc-modified-id="def-trainAutoencoder(x_train,-model):-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span><code>def trainAutoencoder(x_train, model):</code></a></span></li><li><span><a href="#def-plotLoss(history):" data-toc-modified-id="def-plotLoss(history):-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span><code>def plotLoss(history):</code></a></span></li></ul></li><li><span><a href="#Save-plot" data-toc-modified-id="Save-plot-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Save plot</a></span><ul class="toc-item"><li><span><a href="#def-savePlot():" data-toc-modified-id="def-savePlot():-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span><code>def savePlot():</code></a></span></li></ul></li><li><span><a href="#Detecting-anomalies" data-toc-modified-id="Detecting-anomalies-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Detecting anomalies</a></span><ul class="toc-item"><li><span><a href="#def-detectAnomalies(x_train,-x_test):" data-toc-modified-id="def-detectAnomalies(x_train,-x_test):-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span><code>def detectAnomalies(x_train, x_test):</code></a></span></li><li><span><a href="#def-findAnomaliesRange(anomalies,-_train):" data-toc-modified-id="def-findAnomaliesRange(anomalies,-_train):-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span><code>def findAnomaliesRange(anomalies, _train):</code></a></span></li><li><span><a href="#def-plotAnomalies(df_test,-anomalies):" data-toc-modified-id="def-plotAnomalies(df_test,-anomalies):-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span><code>def plotAnomalies(df_test, anomalies):</code></a></span></li></ul></li></ul></li><li><span><a href="#Main" data-toc-modified-id="Main-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Main</a></span><ul class="toc-item"><li><span><a href="#Save-result-in-.csv" data-toc-modified-id="Save-result-in-.csv-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Save result in .csv</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Build,-Train-and-Test-Autoencoder-for-all-data" data-toc-modified-id="Build,-Train-and-Test-Autoencoder-for-all-data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Build, Train and Test Autoencoder for all data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Setup

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from typing import Iterable
from csv import writer

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import scipy.signal as signal
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf

from tensorflow import keras
from tensorflow.keras import layers

from loadData import DataLoader

# %% [markdown]
# # Define Functions

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### `def plotTimeSeries()`

# %%
def plotTimeSeries(df, figsize_n: int = 80, figsize_m: int = 6, title='', title_fontsize=60):
    fig, ax = plt.subplots(figsize=(figsize_n, figsize_m))
    df.plot(legend=False, ax=ax)
    plt.title(title, fontsize=title_fontsize)
    plt.show()

# %% [markdown]
# ## Find window size
#
# http://www.l3s.de/~anand/tir14/lectures/ws14-tir-foundations-2.pdf
#
# Steps to identify `Auto-Period` (i.e. values of x-axis time `t` that the time series signal repeats itself):
# 1. Find the dominant frequency by the highest "power at that freq" using "Power Spectral Density (PSD) Estimation" in the Periodogram
#     p.s. Periodogram encodes the strength at a given frequency
# 2. Use candidate periods from Periodogram, and validate false alarms using Auto-correlation
#
# <img src="../img/periodogram+autocorrelation.png">
#
# After tested in `00-exploratory-data-analysis-(kdd-cup-2021).ipynb`, the `window size` should be smaller OR larger than the `auto-period`, and should not be same as `auto-period`.

# %% [markdown]
# ### `def findDominantFreq():` - Find the freq with strongest strength in Periodogram

# %%
def findDominantFreq(x) -> Iterable[Iterable]:
    '''
    Parameters
    ----------
    x : array_like
        Time series of measurement values

    Return
    ----------
    f: array_like
       Array of sample frequencies.
    Pxx_den: array_like
             Power spectral density or power spectrum of `x`.
    '''
#     freq_ls = [] #
#     Pxx_den_ls = [] #Power spectral density or power spectrum of `x`.

    f, Pxx_den = signal.periodogram(x)
#     freq_ls.append(f[1:])
#     Pxx_den_ls.append(p[1:])

    return f, Pxx_den

# %% [markdown]
# ### `def findAutoPeriod()` - Find the period of the time series data

# %%
def findAutoPeriod(x):
    '''Find the period of the time series data by (1) Periodogram and (2) Auto-correlation

    Steps
    ---
    1. Find the dominant frequency by the highest "power at that freq" using "Power Spectral Density (PSD) Estimation" in the Periodogram
    2. Use candidate periods from Periodogram, and validate false alarms using Auto-correlation

    P.S. Periodogram encodes the strength at a given frequency

    Parameters
    ----------
    x : array_like
        Time series of measurement values
    '''
    freq, Pxx_den = findDominantFreq(x)

    periodicity_df = pd.DataFrame(
        {'freq': freq[1:], 'PSD': Pxx_den[1:], 'Period': 1/freq[1:]}) #skip the 1st element because it is 0.0

    color = ['r', 'b', 'g', 'k', 'c']

    df = periodicity_df

    # Period hints capture from periodogram
    hints = list(round(df[(df["Period"] >= 10)].sort_values(
        'PSD', ascending=False)[:5]['Period']))

    print(hints)
#     plot_acf(x, lags=1000)
#     plt.show()

    acf_record = acf(x, nlags=max(hints), fft=True)

    # plt.plot(x,marker="|")
    # for k in range(len(hints[j])):
    #    plt.axvline(x=hints[j][k],color=color[k])
    # plt.show()

    temp = acf_record[[int(h-1) for h in hints]]
    autoperiod = hints[np.array(temp).argmax()]

    return autoperiod

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### `def normalize(df):`

# %%
def normalize(df: pd.DataFrame,
              df2: pd.DataFrame = None
              ) -> pd.DataFrame:
    '''Normalize data by the mean and std.
    Return the normalized data value
    '''

    msg = 'xxx'
    if df2 is None:
        df2 = df
        msg = 'same'
    else:
        msg = 'other'
    print(f'> Normalizing by {msg} `mean` `std`.')

    _mean = df2.mean()
    _std = df2.std()
    df_value = (df - _mean) / _std

#     print("Number of samples:", len(df_value))

#     display(df)

#     display(df_value)

#     display(df.describe())

#     df_value.describe()

    return df_value

# %% [markdown]
# ## Discretize the Time series data by sliding window
#
# ### `def createSequences(values, time_steps=100):`

# %%
def createSequences(values, time_steps: int = 100):
    '''Generated training sequences for use in the model. Return the discretized time series data.
    
    Parameters
    ----------
    values : array_like
             Time series of measurement values
    '''
    output = []
    for i in range(int(len(values) - time_steps + 1)):
        output.append(values[i: (i + time_steps)])
    return np.stack(output)

# %% [markdown]
# ## Build, Train & Save model

# %% [markdown]
# ### `def buildAutoencoder(train_df, model_name, folder):`

# %%
def buildAutoencoder(shape: tuple,
                     learning_rate=0.01,
                    ):
    '''Build and return the autoencoder.
    '''
    print('> buildAutoencoder(), shape=', shape)
    model = keras.Sequential(
        [
            layers.Input(shape=shape),
            layers.Conv1D(filters=16, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Dropout(rate=0.2),
            layers.Conv1D(filters=8, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Conv1DTranspose(filters=8, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Dropout(rate=0.2),
            layers.Conv1DTranspose(filters=16, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
#             layers.Cropping1D(cropping=(1,1)) # this is the added step
            layers.Reshape(shape)

        ]
    )
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
#     model.summary()

    return model

# %% [markdown]
# ### `def saveAutoencoder(model_name, folder):`

# %%
def saveAutoencoder(model,
                    model_name: str = '',
                    folder: str = 'models/autoencoder',
                   ):
    if not os.path.exists(folder):
        os.makedirs(folder)
    path = f'{folder}/{model_name+".h5"}'
    model.save(path)
    print(f'> Saved `{path}` !')

# %% [markdown]
# ### `def trainAutoencoder(x_train, model):`

# %%
def trainAutoencoder(discretized_X, model, batch_size=32):
    history = model.fit(
        discretized_X,  # x_train_padded_zero,
        discretized_X,  # x_train_padded_zero,
        epochs=50,
        batch_size=batch_size,
        validation_split=0.1,
        callbacks=[
            keras.callbacks.EarlyStopping(
                monitor="val_loss", patience=5, mode="min")
        ],
        verbose=2,
    )
#     plotLoss(history)
    return model, history

# %% [markdown]
# ### `def plotLoss(history):`

# %%
def plotLoss(history):
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.legend()
#     plt.show()

# %% [markdown]
# ## Save plot
#
# ### `def savePlot():`

# %% [markdown]
# ## Detecting anomalies
#
# ### `def detectAnomalies(x_train, x_test):`
#
# https://towardsdatascience.com/master-the-art-of-subplots-in-python-45f7884f3d2e

# %%
class detectAnomalies():

    def __init__(self,
                 model):
        self.x_train = []
        self.x_test = []
        self.x_train_pred = []
        self.train_mae_loss = []
        self.threshold = None
        self.x_test_pred = []
        self.test_mae_loss = []
        self.anomalies = []
        self.anomalies_range = []
        self.anomalies_group = []

    def detect(self, x_train, x_test):
        '''Find and return anomaly'''
        print("> Test input shape: ", x_test.shape)

        # Get train MAE loss.
        x_train_pred = model.predict(x_train)
        train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

        # Get reconstruction loss threshold.
        threshold = np.max(train_mae_loss)
    #     print("Reconstruction error threshold: ", threshold)

        # Get test MAE loss.
        x_test_pred = model.predict(x_test)
        test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
        test_mae_loss = test_mae_loss.reshape((-1))

        # Detect all the samples which are anomalies.
        anomalies = test_mae_loss > threshold
    #     print("Number of anomaly samples: ", np.sum(anomalies))
    #     print("Indices of anomaly samples: ", np.where(anomalies))

        self.x_train = x_train
        self.x_test = x_test
        self.x_train_pred = x_train_pred
        self.train_mae_loss = train_mae_loss
        self.threshold = threshold
        self.x_test_pred = x_test_pred
        self.test_mae_loss = test_mae_loss
        self.anomalies = anomalies

        return anomalies

    def plot(self, plot_title='', save_folder='', ):
        '''
        (1) Plot MAE loss
        (2) Compare recontruction - Test with training data.
            Checking how the first sequence is learnt
        '''
        fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
        fig.suptitle(
            f'{plot_title}, MAE loss and Compare recontruction')

        ax1.hist(self.train_mae_loss, bins=50)
        ax1.set_title('Train MAE loss')
        ax1.set(xlabel='Train MAE loss', ylabel='No of samples')

        ax2.hist(self.test_mae_loss, bins=50)
        ax2.set_title("Test MAE loss")
        ax2.set(xlabel='Test MAE loss', ylabel='No of samples')

        ax3.set_title("Compare recontruction")
        ax3.plot(self.x_train[0], label='origin')
        ax3.plot(self.x_train_pred[0], label='predicted')
#         ax3.axis('equal')

        path = f'{save_folder}/{plot_title}.png'
        plt.savefig(path, facecolor='white', transparent=False)
#         plt.show()
        plt.close()

# %% [markdown]
# ### `def findAnomaliesRange(anomalies, _train):`

# %%
def findAnomaliesRange(anomalies, autoperiod, _train):
    '''https://stackoverflow.com/questions/2361945/detecting-consecutive-integers-in-a-list
    '''
    _a = np.where(anomalies)[0]+len(_train)
    nums = sorted(set(_a))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+autoperiod/2 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return list(zip(edges, edges))


def findAnomaliesRange_v2(anomalies, _train):
    '''https://stackoverflow.com/questions/10016802/grouping-a-list-of-integers-with-nearest-values
    '''
    _a = np.where(anomalies)[0]+len(_train)
    _a.sort()
    diff = [_a[i+1]-_a[i] for i in range(len(_a)-1)]
    avg = sum(diff) / len(diff)
    anomalies_group = [[_a[0]]]
    for x in _a[1:]:
        if x - anomalies_group[-1][-1] < avg:
            anomalies_group[-1].append(x)
        else:
            anomalies_group.append([x])
    return anomalies_group

# %% [markdown]
# ### `def plotAnomalies(df_test, anomalies):`

# %%
def plotAnomalies(df: pd.DataFrame,
                  anomalies: np.array,
                  plot_title: str = '',
                  save_folder=''
                  ):
    df_subset = df.iloc[np.where(anomalies)]
    print('len(df)=', len(df))
#     display(df_subset)

    N, M = 25, 6
    fig, ax = plt.subplots(figsize=(N, M))
    ax.set_title(plot_title)
    df.plot(legend=False, ax=ax)
    df_subset.plot(legend=False, ax=ax, color="r")

#     plt.axvline(int(ans["anomaly_start"][j])-100, color="r")
#     plt.axvline(int(ans["anomaly_end"][j])+100, color="r")

    path = f'{save_folder}/{plot_title}.png'
    print('> plotAnomalies(), path=', path)
    plt.savefig(path, facecolor='white', transparent=False)
#     plt.show()
    plt.close()

# %% [markdown]
# # Main

# %% [markdown]
# ## Save result in .csv

# %%
def appendListAsRow(file_name, list_of_elem):
    '''
    Example
    ---
    
    append_list_as_row('out.csv', [32424, 1124124, 754534])
    '''
    # Open file in append mode
    with open(file_name, 'a+', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = writer(write_obj)
        # Add contents of list as last row in the csv file
        csv_writer.writerow(list_of_elem)

# %% [markdown]
# ## Load data

# %%
path = '../data-sets/KDD-Cup/data/'

loader = DataLoader(path)
loader.loadData()

data_df_list = loader.getDataInDfList()
# Out:
# ..........................................................................................................................................................................................................................................................

# %%
name, data_df = data_df_list[33]

df_train = data_df[data_df['label']=='train']['values'].to_frame()
df_test = data_df[data_df['label']=='test']['values'].to_frame()

display(data_df)

print(name)
print('df_train.shape =', df_train.shape)
print('df_test.shape =', df_test.shape)
# Out:
#          values  label
# 0     76.458008  train
# 1     76.362195  train
# 2     77.233139  train
# 3     77.797305  train
# 4     77.612248  train
# ...         ...    ...
# 7649  45.042070   test
# 7650  46.081865   test
# 7651  45.737770   test
# 7652  45.362732   test
# 7653  45.376655   test
#
# [7654 rows x 2 columns]
# 034_UCR_Anomaly_1500.txt
# df_train.shape = (1500, 1)
# df_test.shape = (6154, 1)

# %% [markdown]
# ## Build, Train and Test Autoencoder for all data

# %%
columns = ['No.', 'Location of Anomaly', 'Window Size']

result_plot_folder = 'results'
if not os.path.exists(result_plot_folder):
    os.makedirs(result_plot_folder)

# %%
for i, (name, data_df) in enumerate(data_df_list):
    print(f'=== {name} ======================================================')

    # Get data
    _train_df = data_df[data_df['label'] == 'train']['values'].to_frame()
    _test_df = data_df[data_df['label'] == 'test']['values'].to_frame()

    # Normalize data
    _train_df_value = normalize(_train_df)
    _test_df_value = normalize(_test_df, _train_df)

#     # Visualization
#     # Plot of train data (without anomaly)
#     plotTimeSeries(_train_df_value, title=f'{name}, Training ')
#     # Plot of test data (with anomaly)
#     plotTimeSeries(_train_df_value, 100, title=f'{name}, Testing')

    # Find autoperiod
    autoperiod = findAutoPeriod(_train_df['values'])
    autoperiod = int(autoperiod)
#     autoperiod += autoperiod % 2
    print('> autoperiod:', autoperiod)

    # Define Window Size
#     time_steps_ls = [autoperiod-int(autoperiod/5), autoperiod+int(autoperiod/5), autoperiod]
    time_steps_ls = [autoperiod]

    for time_steps in time_steps_ls:
        try:
            time_steps += time_steps % 2
            print('=== Window Size =', time_steps)

            # Discretize the normalized time series data
            _train_X = createSequences(_train_df_value.values, time_steps)
            _test_X = createSequences(_test_df_value.values, time_steps)
            print("> Training input shape: ", _train_X.shape)

            # Build model
            model_name = f'{name[:-4]}-{time_steps}windowsize-{autoperiod}autoperiod'

            model = buildAutoencoder(
                shape=(_train_X.shape[1], _train_X.shape[2]))
            # f'{time_steps}windowsize_{autoperiod}autoperiod'
            model._name = model_name
            model.summary()

            # Train model
            batch_size = int(time_steps/5)
            batch_size += batch_size % 2
            print('> batch_size =', batch_size)
            model, history = trainAutoencoder(
                _train_X, model, batch_size=batch_size)

            # Save the trained model
            saveAutoencoder(model, model_name)

            # Test model, detect anomaly
            detector = detectAnomalies(model)
            anomalies = detector.detect(_train_X, _test_X)
            # Save anomalies
            _save = np.where(anomalies)[0]+len(_train_X)
            np.savetxt(f'{result_plot_folder}/anomaly-{model_name}.txt',
                       _save,
                       delimiter=',')
            
#             # Plot Autoencoder result
#             detector.plot(save_folder=result_plot_folder,
#                           plot_title=f'{model_name}-autoencoder')
            anomalies_ranges = findAnomaliesRange(
                anomalies, autoperiod, _train_X)

            print("> Reconstruction error threshold: ", detector.threshold)
            print("> Number of anomaly samples: ", np.sum(anomalies))
#         print("> Indices of anomaly samples: ", np.where(anomalies))
            for _range in anomalies_ranges:
                print("> Indices of anomaly samples: ", np.where(_range))

#             # Plot anomaly position
#             plotAnomalies(df=_test_df,
#                           anomalies=anomalies,
#                           plot_title=f'anomaly-{model_name}__{anomalies_ranges}',
#                           save_folder=result_plot_folder,
#                           )

            keras.backend.clear_session()

            # Save anomalies as submission file
            _ranges = findAnomaliesRange(anomalies, autoperiod, _train_X)
            _ranges_diff = [b-a for a, b in _ranges]
            _max_range = max(_ranges_diff)
            _center_idx = _ranges_diff.index(_max_range)
            _center = int(sum(_ranges[_center_idx])/2)
            print('> _ranges =', _ranges)
            print('> _center =', _center)
            appendListAsRow('submit_file_autoencoder.csv', [name[:3], _center, time_steps])

        except Exception as e:
            print(e)
        print()

#         break
#     break
# Out:
# === 001_UCR_Anomaly_35000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [212.0, 203.0, 211.0, 104.0, 220.0]
# > autoperiod: 211
# === Window Size = 212
# > Training input shape:  (34789, 212, 1)
# > buildAutoencoder(), shape= (212, 1)
# Model: "001_UCR_Anomaly_35000-212windowsize-211autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 106, 16)           80
# _________________________________________________________________
# dropout (Dropout)            (None, 106, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 53, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 106, 8)            264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 106, 8)            0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 212, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 212, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 212, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 42
# Epoch 1/50
# 746/746 - 11s - loss: 0.0260 - val_loss: 0.0487
# Epoch 2/50
# 746/746 - 14s - loss: 0.0073 - val_loss: 0.0999
# Epoch 3/50
# 746/746 - 11s - loss: 0.0056 - val_loss: 0.1401
# Epoch 4/50
# 746/746 - 10s - loss: 0.0049 - val_loss: 0.1388
# Epoch 5/50
# 746/746 - 11s - loss: 0.0043 - val_loss: 0.1537
# Epoch 6/50
# 746/746 - 10s - loss: 0.0041 - val_loss: 0.1653
# > Saved `models/autoencoder/001_UCR_Anomaly_35000-212windowsize-211autoperiod.h5` !
# > Test input shape:  (44584, 212, 1)
# > Reconstruction error threshold:  0.7215365329098992
# > Number of anomaly samples:  448
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(51747, 52051), (69136, 69372)]
# > _center = 51899
#
# === 002_UCR_Anomaly_35000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [212.0, 203.0, 211.0, 104.0, 208.0]
# > autoperiod: 211
# === Window Size = 212
# > Training input shape:  (34789, 212, 1)
# > buildAutoencoder(), shape= (212, 1)
# Model: "002_UCR_Anomaly_35000-212windowsize-211autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 106, 16)           80
# _________________________________________________________________
# dropout (Dropout)            (None, 106, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 53, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 106, 8)            264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 106, 8)            0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 212, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 212, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 212, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 42
# Epoch 1/50
# 746/746 - 20s - loss: 0.0384 - val_loss: 0.0492
# Epoch 2/50
# 746/746 - 10s - loss: 0.0114 - val_loss: 0.1072
# Epoch 3/50
# 746/746 - 8s - loss: 0.0073 - val_loss: 0.1355
# Epoch 4/50
# 746/746 - 13s - loss: 0.0064 - val_loss: 0.1362
# Epoch 5/50
# 746/746 - 14s - loss: 0.0057 - val_loss: 0.1475
# Epoch 6/50
# 746/746 - 13s - loss: 0.0051 - val_loss: 0.1512
# > Saved `models/autoencoder/002_UCR_Anomaly_35000-212windowsize-211autoperiod.h5` !
# > Test input shape:  (44790, 212, 1)
# > Reconstruction error threshold:  0.6835730217433721
# > Number of anomaly samples:  263
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(69321, 69583)]
# > _center = 69452
#
# === 003_UCR_Anomaly_35000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [212.0, 203.0, 211.0, 104.0, 210.0]
# > autoperiod: 210
# === Window Size = 210
# > Training input shape:  (34791, 210, 1)
# > buildAutoencoder(), shape= (210, 1)
# total size of new array must be unchanged, input_shape = [212, 1], output_shape = [210, 1]
#
# === 004_UCR_Anomaly_2500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [81.0, 78.0, 40.0, 83.0, 27.0]
# > autoperiod: 81
# === Window Size = 82
# > Training input shape:  (2419, 82, 1)
# > buildAutoencoder(), shape= (82, 1)
# total size of new array must be unchanged, input_shape = [84, 1], output_shape = [82, 1]
#
# === 005_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 24.0, 571.0, 364.0, 24.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (3977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "005_UCR_Anomaly_4000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 12, 16)            80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose_6 (Conv1DTr (None, 12, 8)             264
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_7 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_8 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 895/895 - 4s - loss: 0.0708 - val_loss: 0.0362
# Epoch 2/50
# 895/895 - 2s - loss: 0.0370 - val_loss: 0.0219
# Epoch 3/50
# 895/895 - 2s - loss: 0.0306 - val_loss: 0.0305
# Epoch 4/50
# 895/895 - 2s - loss: 0.0319 - val_loss: 0.0186
# Epoch 5/50
# 895/895 - 2s - loss: 0.0266 - val_loss: 0.0371
# Epoch 6/50
# 895/895 - 2s - loss: 0.0280 - val_loss: 0.0319
# Epoch 7/50
# 895/895 - 2s - loss: 0.0273 - val_loss: 0.0134
# Epoch 8/50
# 895/895 - 3s - loss: 0.0262 - val_loss: 0.0293
# Epoch 9/50
# 895/895 - 3s - loss: 0.0250 - val_loss: 0.0211
# Epoch 10/50
# 895/895 - 3s - loss: 0.0273 - val_loss: 0.0636
# Epoch 11/50
# 895/895 - 3s - loss: 0.0252 - val_loss: 0.0235
# Epoch 12/50
# 895/895 - 3s - loss: 0.0252 - val_loss: 0.0161
# > Saved `models/autoencoder/005_UCR_Anomaly_4000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (4161, 24, 1)
# > Reconstruction error threshold:  0.281546774882159
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 006_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 24.0, 571.0, 364.0, 24.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (3977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "006_UCR_Anomaly_4000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 12, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 12, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 895/895 - 9s - loss: 0.0818 - val_loss: 0.0233
# Epoch 2/50
# 895/895 - 6s - loss: 0.0416 - val_loss: 0.0347
# Epoch 3/50
# 895/895 - 5s - loss: 0.0324 - val_loss: 0.0238
# Epoch 4/50
# 895/895 - 8s - loss: 0.0278 - val_loss: 0.0351
# Epoch 5/50
# 895/895 - 6s - loss: 0.0284 - val_loss: 0.0261
# Epoch 6/50
# 895/895 - 6s - loss: 0.0273 - val_loss: 0.0281
# > Saved `models/autoencoder/006_UCR_Anomaly_4000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (4161, 24, 1)
# > Reconstruction error threshold:  0.39550799389318775
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 007_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 24.0, 571.0, 24.0, 364.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (3977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "007_UCR_Anomaly_4000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 12, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 12, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 895/895 - 8s - loss: 0.0780 - val_loss: 0.0613
# Epoch 2/50
# 895/895 - 6s - loss: 0.0403 - val_loss: 0.0481
# Epoch 3/50
# 895/895 - 6s - loss: 0.0391 - val_loss: 0.1026
# Epoch 4/50
# 895/895 - 6s - loss: 0.0344 - val_loss: 0.0556
# Epoch 5/50
# 895/895 - 6s - loss: 0.0356 - val_loss: 0.0710
# Epoch 6/50
# 895/895 - 6s - loss: 0.0297 - val_loss: 0.0172
# Epoch 7/50
# 895/895 - 6s - loss: 0.0393 - val_loss: 0.0198
# Epoch 8/50
# 895/895 - 6s - loss: 0.0292 - val_loss: 0.0385
# Epoch 9/50
# 895/895 - 5s - loss: 0.0300 - val_loss: 0.0294
# Epoch 10/50
# 895/895 - 5s - loss: 0.0314 - val_loss: 0.0347
# Epoch 11/50
# 895/895 - 5s - loss: 0.0303 - val_loss: 0.0351
# > Saved `models/autoencoder/007_UCR_Anomaly_4000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (4161, 24, 1)
# > Reconstruction error threshold:  0.4486897553422223
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 008_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 24.0, 571.0, 800.0, 364.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (3977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "008_UCR_Anomaly_4000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 12, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 12, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 895/895 - 3s - loss: 0.0684 - val_loss: 0.0336
# Epoch 2/50
# 895/895 - 2s - loss: 0.0324 - val_loss: 0.0411
# Epoch 3/50
# 895/895 - 2s - loss: 0.0283 - val_loss: 0.0124
# Epoch 4/50
# 895/895 - 2s - loss: 0.0265 - val_loss: 0.0234
# Epoch 5/50
# 895/895 - 2s - loss: 0.0288 - val_loss: 0.0414
# Epoch 6/50
# 895/895 - 2s - loss: 0.0279 - val_loss: 0.0270
# Epoch 7/50
# 895/895 - 2s - loss: 0.0234 - val_loss: 0.0288
# Epoch 8/50
# 895/895 - 2s - loss: 0.0264 - val_loss: 0.0240
# > Saved `models/autoencoder/008_UCR_Anomaly_4000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (4161, 24, 1)
# > Reconstruction error threshold:  0.35757179104265296
# > Number of anomaly samples:  31
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(5516, 5547)]
# > _center = 5531
#
# === 009_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 24.0, 571.0, 364.0, 24.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (3977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "009_UCR_Anomaly_4000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 12, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 12, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 895/895 - 4s - loss: 0.0766 - val_loss: 0.0231
# Epoch 2/50
# 895/895 - 3s - loss: 0.0406 - val_loss: 0.0281
# Epoch 3/50
# 895/895 - 3s - loss: 0.0336 - val_loss: 0.0150
# Epoch 4/50
# 895/895 - 2s - loss: 0.0349 - val_loss: 0.0273
# Epoch 5/50
# 895/895 - 2s - loss: 0.0362 - val_loss: 0.0341
# Epoch 6/50
# 895/895 - 3s - loss: 0.0338 - val_loss: 0.0309
# Epoch 7/50
# 895/895 - 3s - loss: 0.0323 - val_loss: 0.0295
# Epoch 8/50
# 895/895 - 3s - loss: 0.0319 - val_loss: 0.0155
# > Saved `models/autoencoder/009_UCR_Anomaly_4000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (4161, 24, 1)
# > Reconstruction error threshold:  0.33871631627791626
# > Number of anomaly samples:  1
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(5055, 5055)]
# > _center = 5055
#
# === 010_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 24.0, 571.0, 364.0, 24.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (3977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "010_UCR_Anomaly_4000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 12, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 12, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 895/895 - 3s - loss: 0.0808 - val_loss: 0.0394
# Epoch 2/50
# 895/895 - 2s - loss: 0.0325 - val_loss: 0.0527
# Epoch 3/50
# 895/895 - 2s - loss: 0.0305 - val_loss: 0.0278
# Epoch 4/50
# 895/895 - 2s - loss: 0.0268 - val_loss: 0.0475
# Epoch 5/50
# 895/895 - 2s - loss: 0.0268 - val_loss: 0.0518
# Epoch 6/50
# 895/895 - 2s - loss: 0.0264 - val_loss: 0.0285
# Epoch 7/50
# 895/895 - 2s - loss: 0.0264 - val_loss: 0.0197
# Epoch 8/50
# 895/895 - 2s - loss: 0.0246 - val_loss: 0.0214
# Epoch 9/50
# 895/895 - 2s - loss: 0.0258 - val_loss: 0.0195
# Epoch 10/50
# 895/895 - 2s - loss: 0.0255 - val_loss: 0.0346
# Epoch 11/50
# 895/895 - 2s - loss: 0.0250 - val_loss: 0.0272
# Epoch 12/50
# 895/895 - 2s - loss: 0.0251 - val_loss: 0.0240
# Epoch 13/50
# 895/895 - 2s - loss: 0.0244 - val_loss: 0.0354
# Epoch 14/50
# 895/895 - 2s - loss: 0.0244 - val_loss: 0.0392
# > Saved `models/autoencoder/010_UCR_Anomaly_4000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (4161, 24, 1)
# > Reconstruction error threshold:  0.5217644441802772
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 011_UCR_Anomaly_10000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [93.0, 93.0, 23.0, 89.0, 47.0]
# > autoperiod: 93
# === Window Size = 94
# > Training input shape:  (9907, 94, 1)
# > buildAutoencoder(), shape= (94, 1)
# total size of new array must be unchanged, input_shape = [96, 1], output_shape = [94, 1]
#
# === 012_UCR_Anomaly_15000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [90.0, 93.0, 91.0, 89.0, 89.0]
# > autoperiod: 93
# === Window Size = 94
# > Training input shape:  (14907, 94, 1)
# > buildAutoencoder(), shape= (94, 1)
# total size of new array must be unchanged, input_shape = [96, 1], output_shape = [94, 1]
#
# === 013_UCR_Anomaly_15000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [83.0, 82.0, 167.0, 83.0, 165.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (14833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "013_UCR_Anomaly_15000-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 84, 16)            80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 84, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose_6 (Conv1DTr (None, 84, 8)             264
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_7 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_8 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 393/393 - 4s - loss: 0.0561 - val_loss: 0.0457
# Epoch 2/50
# 393/393 - 4s - loss: 0.0177 - val_loss: 0.0760
# Epoch 3/50
# 393/393 - 4s - loss: 0.0134 - val_loss: 0.0775
# Epoch 4/50
# 393/393 - 3s - loss: 0.0119 - val_loss: 0.0694
# Epoch 5/50
# 393/393 - 4s - loss: 0.0109 - val_loss: 0.0774
# Epoch 6/50
# 393/393 - 3s - loss: 0.0105 - val_loss: 0.0814
# > Saved `models/autoencoder/013_UCR_Anomaly_15000-168windowsize-167autoperiod.h5` !
# > Test input shape:  (14833, 168, 1)
# > Reconstruction error threshold:  0.211278163495516
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 014_UCR_Anomaly_8000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [83.0, 167.0, 33.0, 56.0, 28.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (7833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "014_UCR_Anomaly_8000-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 84, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 84, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 208/208 - 3s - loss: 0.0942 - val_loss: 0.0588
# Epoch 2/50
# 208/208 - 2s - loss: 0.0285 - val_loss: 0.0619
# Epoch 3/50
# 208/208 - 2s - loss: 0.0230 - val_loss: 0.0399
# Epoch 4/50
# 208/208 - 2s - loss: 0.0212 - val_loss: 0.0571
# Epoch 5/50
# 208/208 - 2s - loss: 0.0187 - val_loss: 0.0538
# Epoch 6/50
# 208/208 - 2s - loss: 0.0169 - val_loss: 0.0650
# Epoch 7/50
# 208/208 - 2s - loss: 0.0151 - val_loss: 0.0582
# Epoch 8/50
# 208/208 - 2s - loss: 0.0144 - val_loss: 0.0762
# > Saved `models/autoencoder/014_UCR_Anomaly_8000-168windowsize-167autoperiod.h5` !
# > Test input shape:  (21833, 168, 1)
# > Reconstruction error threshold:  0.21469393256827626
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 015_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [455.0, 500.0, 238.0, 417.0, 227.0]
# > autoperiod: 455
# === Window Size = 456
# > Training input shape:  (4545, 456, 1)
# > buildAutoencoder(), shape= (456, 1)
# Model: "015_UCR_Anomaly_5000-456windowsize-455autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 228, 16)           80
# _________________________________________________________________
# dropout (Dropout)            (None, 228, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 114, 8)            520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 228, 8)            264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 228, 8)            0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 456, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 456, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 456, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 92
# Epoch 1/50
# 45/45 - 3s - loss: 0.1587 - val_loss: 0.0131
# Epoch 2/50
# 45/45 - 4s - loss: 0.0255 - val_loss: 0.0176
# Epoch 3/50
# 45/45 - 3s - loss: 0.0149 - val_loss: 0.0325
# Epoch 4/50
# 45/45 - 4s - loss: 0.0108 - val_loss: 0.0340
# Epoch 5/50
# 45/45 - 3s - loss: 0.0092 - val_loss: 0.0323
# Epoch 6/50
# 45/45 - 3s - loss: 0.0078 - val_loss: 0.0321
# > Saved `models/autoencoder/015_UCR_Anomaly_5000-456windowsize-455autoperiod.h5` !
# > Test input shape:  (194545, 456, 1)
# > Reconstruction error threshold:  0.19576104587338075
# > Number of anomaly samples:  643
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(16450, 16610), (26910, 27158), (44409, 44486), (48997, 49085), (130792, 130838), (133718, 133788), (134071, 134187)]
# > _center = 27034
#
# === 016_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [83.0, 167.0, 56.0, 33.0, 42.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (4833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "016_UCR_Anomaly_5000-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 84, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 84, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 128/128 - 3s - loss: 0.1087 - val_loss: 0.0486
# Epoch 2/50
# 128/128 - 1s - loss: 0.0263 - val_loss: 0.0373
# Epoch 3/50
# 128/128 - 2s - loss: 0.0215 - val_loss: 0.0498
# Epoch 4/50
# 128/128 - 1s - loss: 0.0188 - val_loss: 0.0474
# Epoch 5/50
# 128/128 - 1s - loss: 0.0181 - val_loss: 0.0480
# Epoch 6/50
# 128/128 - 2s - loss: 0.0166 - val_loss: 0.0468
# Epoch 7/50
# 128/128 - 1s - loss: 0.0164 - val_loss: 0.0434
# > Saved `models/autoencoder/016_UCR_Anomaly_5000-168windowsize-167autoperiod.h5` !
# > Test input shape:  (24833, 168, 1)
# > Reconstruction error threshold:  0.1563270903572914
# > Number of anomaly samples:  887
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(5635, 5804), (5929, 6475), (6607, 6667), (6783, 6788), (8451, 8452), (11596, 11596), (12247, 12479), (12906, 12906), (13224, 13234), (14709, 14763), (14869, 14878), (15033, 15034), (15363, 15364), (16579, 16595), (16695, 16861), (21870, 21874), (24003, 24010), (24493, 24498), (28069, 28126)]
# > _center = 6202
#
# === 017_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [83.0, 167.0, 56.0, 33.0, 42.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (4833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "017_UCR_Anomaly_5000-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 84, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 84, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 128/128 - 2s - loss: 0.1262 - val_loss: 0.0410
# Epoch 2/50
# 128/128 - 1s - loss: 0.0319 - val_loss: 0.0630
# Epoch 3/50
# 128/128 - 2s - loss: 0.0263 - val_loss: 0.0940
# Epoch 4/50
# 128/128 - 2s - loss: 0.0221 - val_loss: 0.0831
# Epoch 5/50
# 128/128 - 2s - loss: 0.0200 - val_loss: 0.1044
# Epoch 6/50
# 128/128 - 1s - loss: 0.0180 - val_loss: 0.0806
# > Saved `models/autoencoder/017_UCR_Anomaly_5000-168windowsize-167autoperiod.h5` !
# > Test input shape:  (24833, 168, 1)
# > Reconstruction error threshold:  0.24762289789049896
# > Number of anomaly samples:  682
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(5636, 5771), (6290, 6294), (6539, 6676), (9114, 9154), (12335, 12486), (13226, 13230), (16465, 16595), (16692, 16876), (23353, 23353), (23516, 23517), (26306, 26307), (28025, 28186)]
# > _center = 16784
#
# === 018_UCR_Anomaly_8000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [83.0, 167.0, 33.0, 56.0, 28.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (7833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "018_UCR_Anomaly_8000-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 84, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 84, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 208/208 - 3s - loss: 0.0808 - val_loss: 0.0594
# Epoch 2/50
# 208/208 - 2s - loss: 0.0278 - val_loss: 0.0435
# Epoch 3/50
# 208/208 - 2s - loss: 0.0224 - val_loss: 0.0744
# Epoch 4/50
# 208/208 - 3s - loss: 0.0201 - val_loss: 0.0787
# Epoch 5/50
# 208/208 - 2s - loss: 0.0179 - val_loss: 0.0847
# Epoch 6/50
# 208/208 - 2s - loss: 0.0165 - val_loss: 0.0963
# Epoch 7/50
# 208/208 - 2s - loss: 0.0161 - val_loss: 0.0870
# > Saved `models/autoencoder/018_UCR_Anomaly_8000-168windowsize-167autoperiod.h5` !
# > Test input shape:  (21833, 168, 1)
# > Reconstruction error threshold:  0.23708884128692478
# > Number of anomaly samples:  16
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(12344, 12413)]
# > _center = 12378
#
# === 019_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [217.0, 72.0, 109.0, 54.0, 43.0]
# > autoperiod: 217
# === Window Size = 218
# > Training input shape:  (4783, 218, 1)
# > buildAutoencoder(), shape= (218, 1)
# total size of new array must be unchanged, input_shape = [220, 1], output_shape = [218, 1]
#
# === 020_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [217.0, 72.0, 109.0, 54.0, 43.0]
# > autoperiod: 217
# === Window Size = 218
# > Training input shape:  (4783, 218, 1)
# > buildAutoencoder(), shape= (218, 1)
# total size of new array must be unchanged, input_shape = [220, 1], output_shape = [218, 1]
#
# === 021_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [217.0, 72.0, 109.0, 54.0, 43.0]
# > autoperiod: 217
# === Window Size = 218
# > Training input shape:  (4783, 218, 1)
# > buildAutoencoder(), shape= (218, 1)
# total size of new array must be unchanged, input_shape = [220, 1], output_shape = [218, 1]
#
# === 022_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [222.0, 211.0, 73.0, 108.0, 54.0]
# > autoperiod: 222
# === Window Size = 222
# > Training input shape:  (3779, 222, 1)
# > buildAutoencoder(), shape= (222, 1)
# total size of new array must be unchanged, input_shape = [224, 1], output_shape = [222, 1]
#
# === 023_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [217.0, 72.0, 109.0, 54.0, 43.0]
# > autoperiod: 217
# === Window Size = 218
# > Training input shape:  (4783, 218, 1)
# > buildAutoencoder(), shape= (218, 1)
# total size of new array must be unchanged, input_shape = [220, 1], output_shape = [218, 1]
#
# === 024_UCR_Anomaly_3200.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [152.0, 160.0, 78.0, 76.0, 145.0]
# > autoperiod: 152
# === Window Size = 152
# > Training input shape:  (3049, 152, 1)
# > buildAutoencoder(), shape= (152, 1)
# Model: "024_UCR_Anomaly_3200-152windowsize-152autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 76, 16)            80
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 76, 16)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 38, 8)             520
# _________________________________________________________________
# conv1d_transpose_15 (Conv1DT (None, 76, 8)             264
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 76, 8)             0
# _________________________________________________________________
# conv1d_transpose_16 (Conv1DT (None, 152, 16)           528
# _________________________________________________________________
# conv1d_transpose_17 (Conv1DT (None, 152, 1)            113
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 152, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 30
# Epoch 1/50
# 92/92 - 4s - loss: 0.1015 - val_loss: 0.0600
# Epoch 2/50
# 92/92 - 1s - loss: 0.0176 - val_loss: 0.0487
# Epoch 3/50
# 92/92 - 1s - loss: 0.0126 - val_loss: 0.0210
# Epoch 4/50
# 92/92 - 1s - loss: 0.0107 - val_loss: 0.0273
# Epoch 5/50
# 92/92 - 1s - loss: 0.0093 - val_loss: 0.0278
# Epoch 6/50
# 92/92 - 1s - loss: 0.0086 - val_loss: 0.0479
# Epoch 7/50
# 92/92 - 1s - loss: 0.0081 - val_loss: 0.0216
# Epoch 8/50
# 92/92 - 1s - loss: 0.0074 - val_loss: 0.0297
# > Saved `models/autoencoder/024_UCR_Anomaly_3200-152windowsize-152autoperiod.h5` !
# > Test input shape:  (4150, 152, 1)
# > Reconstruction error threshold:  0.17027484080634966
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 025_UCR_Anomaly_2800.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [156.0, 78.0, 31.0, 147.0, 76.0]
# > autoperiod: 156
# === Window Size = 156
# > Training input shape:  (2645, 156, 1)
# > buildAutoencoder(), shape= (156, 1)
# Model: "025_UCR_Anomaly_2800-156windowsize-156autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 78, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 78, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 39, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 78, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 78, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 156, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 156, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 156, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 32
# Epoch 1/50
# 75/75 - 2s - loss: 0.1666 - val_loss: 0.0484
# Epoch 2/50
# 75/75 - 1s - loss: 0.0224 - val_loss: 0.0435
# Epoch 3/50
# 75/75 - 1s - loss: 0.0147 - val_loss: 0.0336
# Epoch 4/50
# 75/75 - 1s - loss: 0.0122 - val_loss: 0.0318
# Epoch 5/50
# 75/75 - 1s - loss: 0.0111 - val_loss: 0.0489
# Epoch 6/50
# 75/75 - 1s - loss: 0.0100 - val_loss: 0.0384
# Epoch 7/50
# 75/75 - 1s - loss: 0.0092 - val_loss: 0.0382
# Epoch 8/50
# 75/75 - 1s - loss: 0.0082 - val_loss: 0.0399
# Epoch 9/50
# 75/75 - 1s - loss: 0.0078 - val_loss: 0.0586
# > Saved `models/autoencoder/025_UCR_Anomaly_2800-156windowsize-156autoperiod.h5` !
# > Test input shape:  (4546, 156, 1)
# > Reconstruction error threshold:  0.2367296229459957
# > Number of anomaly samples:  0
# max() arg is an empty sequence
#
# === 026_UCR_Anomaly_1700.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [170.0, 85.0, 89.0, 44.0, 1700.0]
# > autoperiod: 170
# === Window Size = 170
# > Training input shape:  (1531, 170, 1)
# > buildAutoencoder(), shape= (170, 1)
# total size of new array must be unchanged, input_shape = [172, 1], output_shape = [170, 1]
#
# === 027_UCR_Anomaly_1200.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [171.0, 200.0, 92.0, 1200.0, 240.0]
# > autoperiod: 171
# === Window Size = 172
# > Training input shape:  (1029, 172, 1)
# > buildAutoencoder(), shape= (172, 1)
# Model: "027_UCR_Anomaly_1200-172windowsize-171autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 86, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 86, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 43, 8)             520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 86, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 86, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 172, 16)           528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 172, 1)            113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 172, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# ...
# > batch_size = 12
# Epoch 1/50
# 198/198 - 2s - loss: 0.1349 - val_loss: 0.0471
# Epoch 2/50
# 198/198 - 1s - loss: 0.0407 - val_loss: 0.0382
# Epoch 3/50
# 198/198 - 1s - loss: 0.0309 - val_loss: 0.0375
# Epoch 4/50
# 198/198 - 1s - loss: 0.0278 - val_loss: 0.0467
# Epoch 5/50
# 198/198 - 1s - loss: 0.0239 - val_loss: 0.0359
# Epoch 6/50
# 198/198 - 1s - loss: 0.0226 - val_loss: 0.0304
# Epoch 7/50
# 198/198 - 1s - loss: 0.0211 - val_loss: 0.0335
# Epoch 8/50
# 198/198 - 1s - loss: 0.0196 - val_loss: 0.0312
# Epoch 9/50
# 198/198 - 1s - loss: 0.0178 - val_loss: 0.0328
# Epoch 10/50
# 198/198 - 1s - loss: 0.0168 - val_loss: 0.0452
# Epoch 11/50
# 198/198 - 1s - loss: 0.0160 - val_loss: 0.0361
# > Saved `models/autoencoder/054_UCR_Anomaly_2700-60windowsize-59autoperiod.h5` !
# > Test input shape:  (3925, 60, 1)
# > Reconstruction error threshold:  0.30481754754425927
# > Number of anomaly samples:  207
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(2874, 2883), (3107, 3113), (3995, 4023), (5362, 5364), (5477, 5482), (5679, 5711), (5802, 5910), (5948, 5968), (6043, 6054)]
# > _center = 5856
#
# === 055_UCR_Anomaly_10000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [90.0, 46.0, 59.0, 93.0, 63.0]
# > autoperiod: 46
# === Window Size = 46
# > Training input shape:  (9955, 46, 1)
# > buildAutoencoder(), shape= (46, 1)
# total size of new array must be unchanged, input_shape = [48, 1], output_shape = [46, 1]
#
# === 056_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [51.0, 500.0, 46.0, 2500.0, 32.0]
# > autoperiod: 2500
# === Window Size = 2500
# > Training input shape:  (2501, 2500, 1)
# > buildAutoencoder(), shape= (2500, 1)
# Model: "056_UCR_Anomaly_5000-2500windowsize-2500autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 1250, 16)          80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1250, 16)          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 625, 8)            520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 1250, 8)           264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1250, 8)           0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 2500, 16)          528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 2500, 1)           113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2500, 1)           0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 500
# Epoch 1/50
# 5/5 - 9s - loss: 1.0265 - val_loss: 0.6571
# Epoch 2/50
# 5/5 - 6s - loss: 0.6354 - val_loss: 0.3609
# Epoch 3/50
# 5/5 - 5s - loss: 0.3499 - val_loss: 0.1780
# Epoch 4/50
# 5/5 - 5s - loss: 0.2287 - val_loss: 0.1487
# Epoch 5/50
# 5/5 - 7s - loss: 0.2020 - val_loss: 0.0907
# Epoch 6/50
# 5/5 - 7s - loss: 0.1450 - val_loss: 0.0643
# Epoch 7/50
# 5/5 - 4s - loss: 0.1289 - val_loss: 0.0552
# Epoch 8/50
# 5/5 - 4s - loss: 0.1106 - val_loss: 0.0349
# Epoch 9/50
# 5/5 - 3s - loss: 0.0950 - val_loss: 0.0298
# Epoch 10/50
# 5/5 - 5s - loss: 0.0872 - val_loss: 0.0213
# Epoch 11/50
# 5/5 - 3s - loss: 0.0795 - val_loss: 0.0212
# Epoch 12/50
# 5/5 - 4s - loss: 0.0747 - val_loss: 0.0212
# Epoch 13/50
# 5/5 - 5s - loss: 0.0699 - val_loss: 0.0185
# Epoch 14/50
# 5/5 - 4s - loss: 0.0665 - val_loss: 0.0172
# Epoch 15/50
# 5/5 - 4s - loss: 0.0632 - val_loss: 0.0194
# Epoch 16/50
# 5/5 - 4s - loss: 0.0590 - val_loss: 0.0171
# Epoch 17/50
# 5/5 - 3s - loss: 0.0552 - val_loss: 0.0177
# Epoch 18/50
# 5/5 - 3s - loss: 0.0519 - val_loss: 0.0228
# Epoch 19/50
# 5/5 - 3s - loss: 0.0491 - val_loss: 0.0254
# Epoch 20/50
# 5/5 - 4s - loss: 0.0462 - val_loss: 0.0292
# Epoch 21/50
# 5/5 - 4s - loss: 0.0434 - val_loss: 0.0313
# > Saved `models/autoencoder/056_UCR_Anomaly_5000-2500windowsize-2500autoperiod.h5` !
# > Test input shape:  (30880, 2500, 1)
# > Reconstruction error threshold:  0.0999951100470261
# > Number of anomaly samples:  1801
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(2539, 3345), (7056, 7986), (21096, 22022), (23575, 23787), (27026, 28639)]
# > _center = 27832
#
# === 057_UCR_Anomaly_6000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [50.0, 125.0, 90.0, 42.0, 71.0]
# > autoperiod: 42
# === Window Size = 42
# > Training input shape:  (5959, 42, 1)
# > buildAutoencoder(), shape= (42, 1)
# total size of new array must be unchanged, input_shape = [44, 1], output_shape = [42, 1]
#
# === 058_UCR_Anomaly_10000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [90.0, 100.0, 46.0, 169.0, 63.0]
# > autoperiod: 100
# === Window Size = 100
# > Training input shape:  (9901, 100, 1)
# > buildAutoencoder(), shape= (100, 1)
# Model: "058_UCR_Anomaly_10000-100windowsize-100autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 50, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 25, 8)             520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 50, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 100, 16)           528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 100, 1)            113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 100, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 20
# Epoch 1/50
# 446/446 - 5s - loss: 0.0985 - val_loss: 0.0412
# Epoch 2/50
# 446/446 - 3s - loss: 0.0395 - val_loss: 0.0517
# Epoch 3/50
# 446/446 - 3s - loss: 0.0365 - val_loss: 0.0417
# Epoch 4/50
# 446/446 - 3s - loss: 0.0361 - val_loss: 0.0550
# Epoch 5/50
# 446/446 - 3s - loss: 0.0321 - val_loss: 0.0779
# Epoch 6/50
# 446/446 - 3s - loss: 0.0267 - val_loss: 0.1024
# > Saved `models/autoencoder/058_UCR_Anomaly_10000-100windowsize-100autoperiod.h5` !
# > Test input shape:  (28402, 100, 1)
# > Reconstruction error threshold:  0.602071071414964
# > Number of anomaly samples:  31
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(20830, 20882), (26817, 26818), (27833, 27850), (34100, 34113)]
# > _center = 20856
#
# === 059_UCR_Anomaly_20000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [312.0, 328.0, 317.0, 156.0, 308.0]
# > autoperiod: 312
# === Window Size = 312
# > Training input shape:  (19689, 312, 1)
# > buildAutoencoder(), shape= (312, 1)
# Model: "059_UCR_Anomaly_20000-312windowsize-312autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 156, 16)           80
# _________________________________________________________________
# dropout (Dropout)            (None, 156, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 78, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 156, 8)            264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 156, 8)            0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 312, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 312, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 312, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 62
# Epoch 1/50
# 286/286 - 8s - loss: 0.0387 - val_loss: 0.0331
# Epoch 2/50
# 286/286 - 8s - loss: 0.0063 - val_loss: 0.0223
# Epoch 3/50
# 286/286 - 5s - loss: 0.0042 - val_loss: 0.0137
# Epoch 4/50
# 286/286 - 6s - loss: 0.0034 - val_loss: 0.0128
# Epoch 5/50
# 286/286 - 5s - loss: 0.0029 - val_loss: 0.0119
# Epoch 6/50
# 286/286 - 5s - loss: 0.0027 - val_loss: 0.0121
# Epoch 7/50
# 286/286 - 6s - loss: 0.0026 - val_loss: 0.0079
# Epoch 8/50
# 286/286 - 9s - loss: 0.0024 - val_loss: 0.0120
# Epoch 9/50
# 286/286 - 7s - loss: 0.0023 - val_loss: 0.0117
# Epoch 10/50
# 286/286 - 5s - loss: 0.0022 - val_loss: 0.0098
# Epoch 11/50
# 286/286 - 7s - loss: 0.0022 - val_loss: 0.0118
# Epoch 12/50
# 286/286 - 8s - loss: 0.0021 - val_loss: 0.0105
# > Saved `models/autoencoder/059_UCR_Anomaly_20000-312windowsize-312autoperiod.h5` !
# > Test input shape:  (44689, 312, 1)
# > Reconstruction error threshold:  0.11592002759258258
# > Number of anomaly samples:  1647
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > _ranges = [(22468, 22480), (27310, 27563), (30328, 30538), (39094, 39182), (42683, 42948), (48557, 48844), (49260, 49260), (50774, 50838), (51168, 51168), (51332, 51388), (51759, 51824), (53330, 53698), (53886, 53910), (54497, 54581), (56171, 56358), (57642, 58215), (58758, 58878)]
# > _center = 57928
#
# === 060_UCR_Anomaly_22000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [314.0, 310.0, 319.0, 156.0, 158.0]
# > autoperiod: 314
# === Window Size = 314
# > Training input shape:  (21687, 314, 1)
# > buildAutoencoder(), shape= (314, 1)
# total size of new array must be unchanged, input_shape = [316, 1], output_shape = [314, 1]
#
# === 061_UCR_Anomaly_24500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [314.0, 310.0, 318.0, 156.0, 327.0]
# > autoperiod: 314
# === Window Size = 314
# > Training input shape:  (24187, 314, 1)
# > buildAutoencoder(), shape= (314, 1)
# total size of new array must be unchanged, input_shape = [316, 1], output_shape = [314, 1]
#
# === 062_UCR_Anomaly_18500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [325.0, 336.0, 343.0, 330.0, 319.0]
# > autoperiod: 330
# === Window Size = 330
# > Training input shape:  (18171, 330, 1)
# > buildAutoencoder(), shape= (330, 1)
# total size of new array must be unchanged, input_shape = [332, 1], output_shape = [330, 1]
#
# === 063_UCR_Anomaly_18500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [325.0, 336.0, 343.0, 330.0, 349.0]
# > autoperiod: 330
# === Window Size = 330
# > Training input shape:  (18171, 330, 1)
# > buildAutoencoder(), shape= (330, 1)
# total size of new array must be unchanged, input_shape = [332, 1], output_shape = [330, 1]
#
# === 064_UCR_Anomaly_23400.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [321.0, 334.0, 325.0, 339.0, 316.0]
# > autoperiod: 334
# === Window Size = 334
# > Training input shape:  (23067, 334, 1)
# > buildAutoencoder(), shape= (334, 1)
# total size of new array must be unchanged, input_shape = [336, 1], output_shape = [334, 1]
#
# === 065_UCR_Anomaly_3000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [26.0, 26.0, 27.0, 26.0, 13.0]
# > autoperiod: 27
# === Window Size = 28
# > Training input shape:  (2973, 28, 1)
# > buildAutoencoder(), shape= (28, 1)
# Model: "065_UCR_Anomaly_3000-28windowsize-27autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 14, 16)            80
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 14, 16)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 7, 8)              520
# _________________________________________________________________
# conv1d_transpose_15 (Conv1DT (None, 14, 8)             264
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 14, 8)             0
# _________________________________________________________________
# conv1d_transpose_16 (Conv1DT (None, 28, 16)            528
# _________________________________________________________________
# conv1d_transpose_17 (Conv1DT (None, 28, 1)             113
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 28, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 6
# Epoch 1/50

# %%
# model = keras.models.load_model('models/autoencoder/001_UCR_Anomaly_35000-132_windowsize-212_autoperiod.h5')

# detector = detectAnomalies(model)
# anomalies = detector.detect(_train_X, _test_X)
# detector.plot(save_folder = result_plot_folder,
#               plot_title = model_name)

# %%
# anomalies_ranges = findAnomaliesRange(anomalies, autoperiod, _train_X)
# anomalies_ranges
# [b-a for a,b in anomalies_ranges]

# %%
# _save = np.where(anomalies)[0]+len(_train_X)

# print(_save)
# np.savetxt('test.out', _save, delimiter=',')   # X is an array

# %%
# keras.backend.clear_session()
# del model

# %%
keras.__version__
