# %% [markdown]
# Reference
#
# https://keras.io/examples/timeseries/timeseries_anomaly_detection/

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Define-Functions" data-toc-modified-id="Define-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Define Functions</a></span><ul class="toc-item"><li><span><a href="#Visualization" data-toc-modified-id="Visualization-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Visualization</a></span><ul class="toc-item"><li><span><a href="#def-plotTimeSeries()" data-toc-modified-id="def-plotTimeSeries()-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span><code>def plotTimeSeries()</code></a></span></li></ul></li><li><span><a href="#Find-window-size" data-toc-modified-id="Find-window-size-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Find window size</a></span><ul class="toc-item"><li><span><a href="#def-findDominantFreq():---Find-the-freq-with-strongest-strength-in-Periodogram" data-toc-modified-id="def-findDominantFreq():---Find-the-freq-with-strongest-strength-in-Periodogram-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span><code>def findDominantFreq():</code> - Find the freq with strongest strength in Periodogram</a></span></li><li><span><a href="#def-findAutoPeriod()---Find-the-period-of-the-time-series-data" data-toc-modified-id="def-findAutoPeriod()---Find-the-period-of-the-time-series-data-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span><code>def findAutoPeriod()</code> - Find the period of the time series data</a></span></li></ul></li><li><span><a href="#Prepare-Data" data-toc-modified-id="Prepare-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Prepare Data</a></span><ul class="toc-item"><li><span><a href="#def-normalize(df):" data-toc-modified-id="def-normalize(df):-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span><code>def normalize(df):</code></a></span></li></ul></li><li><span><a href="#Discretize-the-Time-series-data-by-sliding-window" data-toc-modified-id="Discretize-the-Time-series-data-by-sliding-window-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Discretize the Time series data by sliding window</a></span><ul class="toc-item"><li><span><a href="#def-createSequences(values,-time_steps=100):" data-toc-modified-id="def-createSequences(values,-time_steps=100):-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span><code>def createSequences(values, time_steps=100):</code></a></span></li></ul></li><li><span><a href="#Build,-Train-&amp;-Save-model" data-toc-modified-id="Build,-Train-&amp;-Save-model-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Build, Train &amp; Save model</a></span><ul class="toc-item"><li><span><a href="#def-buildAutoencoder(train_df,-model_name,-folder):" data-toc-modified-id="def-buildAutoencoder(train_df,-model_name,-folder):-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span><code>def buildAutoencoder(train_df, model_name, folder):</code></a></span></li><li><span><a href="#def-saveAutoencoder(model_name,-folder):" data-toc-modified-id="def-saveAutoencoder(model_name,-folder):-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span><code>def saveAutoencoder(model_name, folder):</code></a></span></li><li><span><a href="#def-trainAutoencoder(x_train,-model):" data-toc-modified-id="def-trainAutoencoder(x_train,-model):-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span><code>def trainAutoencoder(x_train, model):</code></a></span></li><li><span><a href="#def-plotLoss(history):" data-toc-modified-id="def-plotLoss(history):-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span><code>def plotLoss(history):</code></a></span></li></ul></li><li><span><a href="#Save-plot" data-toc-modified-id="Save-plot-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Save plot</a></span><ul class="toc-item"><li><span><a href="#def-savePlot():" data-toc-modified-id="def-savePlot():-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span><code>def savePlot():</code></a></span></li></ul></li><li><span><a href="#Detecting-anomalies" data-toc-modified-id="Detecting-anomalies-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Detecting anomalies</a></span><ul class="toc-item"><li><span><a href="#def-detectAnomalies(x_train,-x_test):" data-toc-modified-id="def-detectAnomalies(x_train,-x_test):-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span><code>def detectAnomalies(x_train, x_test):</code></a></span></li><li><span><a href="#def-findAnomaliesRange(anomalies,-_train):" data-toc-modified-id="def-findAnomaliesRange(anomalies,-_train):-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span><code>def findAnomaliesRange(anomalies, _train):</code></a></span></li><li><span><a href="#def-plotAnomalies(df_test,-anomalies):" data-toc-modified-id="def-plotAnomalies(df_test,-anomalies):-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span><code>def plotAnomalies(df_test, anomalies):</code></a></span></li></ul></li></ul></li><li><span><a href="#Main" data-toc-modified-id="Main-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Main</a></span><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Build,-Train-and-Test-Autoencoder-for-all-data" data-toc-modified-id="Build,-Train-and-Test-Autoencoder-for-all-data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Build, Train and Test Autoencoder for all data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Setup

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from typing import Iterable

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import scipy.signal as signal
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf

from tensorflow import keras
from tensorflow.keras import layers

from loadData import DataLoader

# %% [markdown]
# # Define Functions

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### `def plotTimeSeries()`

# %%
def plotTimeSeries(df, figsize_n: int = 80, figsize_m: int = 6, title='', title_fontsize=60):
    fig, ax = plt.subplots(figsize=(figsize_n, figsize_m))
    df.plot(legend=False, ax=ax)
    plt.title(title, fontsize=title_fontsize)
    plt.show()

# %% [markdown]
# ## Find window size
#
# http://www.l3s.de/~anand/tir14/lectures/ws14-tir-foundations-2.pdf
#
# Steps to identify `Auto-Period` (i.e. values of x-axis time `t` that the time series signal repeats itself):
# 1. Find the dominant frequency by the highest "power at that freq" using "Power Spectral Density (PSD) Estimation" in the Periodogram
#     p.s. Periodogram encodes the strength at a given frequency
# 2. Use candidate periods from Periodogram, and validate false alarms using Auto-correlation
#
# <img src="../img/periodogram+autocorrelation.png">
#
# After tested in `00-exploratory-data-analysis-(kdd-cup-2021).ipynb`, the `window size` should be smaller OR larger than the `auto-period`, and should not be same as `auto-period`.

# %% [markdown]
# ### `def findDominantFreq():` - Find the freq with strongest strength in Periodogram

# %%
def findDominantFreq(x) -> Iterable[Iterable]:
    '''
    Parameters
    ----------
    x : array_like
        Time series of measurement values

    Return
    ----------
    f: array_like
       Array of sample frequencies.
    Pxx_den: array_like
             Power spectral density or power spectrum of `x`.
    '''
#     freq_ls = [] #
#     Pxx_den_ls = [] #Power spectral density or power spectrum of `x`.

    f, Pxx_den = signal.periodogram(x)
#     freq_ls.append(f[1:])
#     Pxx_den_ls.append(p[1:])

    return f, Pxx_den

# %% [markdown]
# ### `def findAutoPeriod()` - Find the period of the time series data

# %%
def findAutoPeriod(x):
    '''Find the period of the time series data by (1) Periodogram and (2) Auto-correlation

    Steps
    ---
    1. Find the dominant frequency by the highest "power at that freq" using "Power Spectral Density (PSD) Estimation" in the Periodogram
    2. Use candidate periods from Periodogram, and validate false alarms using Auto-correlation

    P.S. Periodogram encodes the strength at a given frequency

    Parameters
    ----------
    x : array_like
        Time series of measurement values
    '''
    freq, Pxx_den = findDominantFreq(x)

    periodicity_df = pd.DataFrame(
        {'freq': freq[1:], 'PSD': Pxx_den[1:], 'Period': 1/freq[1:]}) #skip the 1st element because it is 0.0

    color = ['r', 'b', 'g', 'k', 'c']

    df = periodicity_df

    # Period hints capture from periodogram
    hints = list(round(df[(df["Period"] >= 10)].sort_values(
        'PSD', ascending=False)[:5]['Period']))

    print(hints)
#     plot_acf(x, lags=1000)
#     plt.show()

    acf_record = acf(x, nlags=max(hints), fft=True)

    # plt.plot(x,marker="|")
    # for k in range(len(hints[j])):
    #    plt.axvline(x=hints[j][k],color=color[k])
    # plt.show()

    temp = acf_record[[int(h-1) for h in hints]]
    autoperiod = hints[np.array(temp).argmax()]

    return autoperiod

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### `def normalize(df):`

# %%
def normalize(df: pd.DataFrame,
              df2: pd.DataFrame = None
              ) -> pd.DataFrame:
    '''Normalize data by the mean and std.
    Return the normalized data value
    '''

    msg = 'xxx'
    if df2 is None:
        df2 = df
        msg = 'same'
    else:
        msg = 'other'
    print(f'> Normalizing by {msg} `mean` `std`.')

    _mean = df2.mean()
    _std = df2.std()
    df_value = (df - _mean) / _std

#     print("Number of samples:", len(df_value))

#     display(df)

#     display(df_value)

#     display(df.describe())

#     df_value.describe()

    return df_value

# %% [markdown]
# ## Discretize the Time series data by sliding window
#
# ### `def createSequences(values, time_steps=100):`

# %%
def createSequences(values, time_steps: int = 100):
    '''Generated training sequences for use in the model. Return the discretized time series data.
    
    Parameters
    ----------
    values : array_like
             Time series of measurement values
    '''
    output = []
    for i in range(int(len(values) - time_steps + 1)):
        output.append(values[i: (i + time_steps)])
    return np.stack(output)

# %% [markdown]
# ## Build, Train & Save model

# %% [markdown]
# ### `def buildAutoencoder(train_df, model_name, folder):`

# %%
def buildAutoencoder(shape: tuple,
                     learning_rate=0.01,
                    ):
    print('> buildAutoencoder(), shape=', shape)
    model = keras.Sequential(
        [
            layers.Input(shape=shape),
            layers.Conv1D(filters=16, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Dropout(rate=0.2),
            layers.Conv1D(filters=8, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Conv1DTranspose(filters=8, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Dropout(rate=0.2),
            layers.Conv1DTranspose(filters=16, kernel_size=4, padding="same", strides=2, activation="relu"),
            layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
#             layers.Cropping1D(cropping=(1,1)) # this is the added step
            layers.Reshape(shape)

        ]
    )
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
#     model.summary()

    return model

# %% [markdown]
# ### `def saveAutoencoder(model_name, folder):`

# %%
def saveAutoencoder(model,
                    model_name: str = '',
                    folder: str = 'models/autoencoder',
                   ):
    if not os.path.exists(folder):
        os.makedirs(folder)
    path = f'{folder}/{model_name+".h5"}'
    model.save(path)
    print(f'> Saved `{path}` !')

# %% [markdown]
# ### `def trainAutoencoder(x_train, model):`

# %%
def trainAutoencoder(discretized_X, model, batch_size=32):
    history = model.fit(
        discretized_X,  # x_train_padded_zero,
        discretized_X,  # x_train_padded_zero,
        epochs=50,
        batch_size=batch_size,
        validation_split=0.1,
        callbacks=[
            keras.callbacks.EarlyStopping(
                monitor="val_loss", patience=5, mode="min")
        ],
        verbose=2,
    )
#     plotLoss(history)
    return model, history

# %% [markdown]
# ### `def plotLoss(history):`

# %%
def plotLoss(history):
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.legend()
#     plt.show()

# %% [markdown]
# ## Save plot
#
# ### `def savePlot():`

# %% [markdown]
# ## Detecting anomalies
#
# ### `def detectAnomalies(x_train, x_test):`
#
# https://towardsdatascience.com/master-the-art-of-subplots-in-python-45f7884f3d2e

# %%
class detectAnomalies():

    def __init__(self,
                 model):
        self.x_train = []
        self.x_test = []
        self.x_train_pred = []
        self.train_mae_loss = []
        self.threshold = None
        self.x_test_pred = []
        self.test_mae_loss = []
        self.anomalies = []
        self.anomalies_range = []
        self.anomalies_group = []

    def detect(self, x_train, x_test):
        '''Find and return anomaly'''
        print("> Test input shape: ", x_test.shape)

        # Get train MAE loss.
        x_train_pred = model.predict(x_train)
        train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

        # Get reconstruction loss threshold.
        threshold = np.max(train_mae_loss)
    #     print("Reconstruction error threshold: ", threshold)

        # Get test MAE loss.
        x_test_pred = model.predict(x_test)
        test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
        test_mae_loss = test_mae_loss.reshape((-1))

        # Detect all the samples which are anomalies.
        anomalies = test_mae_loss > threshold
    #     print("Number of anomaly samples: ", np.sum(anomalies))
    #     print("Indices of anomaly samples: ", np.where(anomalies))

        self.x_train = x_train
        self.x_test = x_test
        self.x_train_pred = x_train_pred
        self.train_mae_loss = train_mae_loss
        self.threshold = threshold
        self.x_test_pred = x_test_pred
        self.test_mae_loss = test_mae_loss
        self.anomalies = anomalies

        return anomalies

    def plot(self, plot_title='', save_folder='', ):
        '''
        (1) Plot MAE loss
        (2) Compare recontruction - Test with training data.
            Checking how the first sequence is learnt
        '''
        fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
        fig.suptitle(
            f'{plot_title}, MAE loss and Compare recontruction')

        ax1.hist(self.train_mae_loss, bins=50)
        ax1.set_title('Train MAE loss')
        ax1.set(xlabel='Train MAE loss', ylabel='No of samples')

        ax2.hist(self.test_mae_loss, bins=50)
        ax2.set_title("Test MAE loss")
        ax2.set(xlabel='Test MAE loss', ylabel='No of samples')

        ax3.set_title("Compare recontruction")
        ax3.plot(self.x_train[0], label='origin')
        ax3.plot(self.x_train_pred[0], label='predicted')
#         ax3.axis('equal')

        path = f'{save_folder}/{plot_title}.png'
        plt.savefig(path, facecolor='white', transparent=False)
#         plt.show()
        plt.close()

# %% [markdown]
# ### `def findAnomaliesRange(anomalies, _train):`

# %%
def findAnomaliesRange(anomalies, autoperiod, _train):
    '''https://stackoverflow.com/questions/2361945/detecting-consecutive-integers-in-a-list
    '''
    _a = np.where(anomalies)[0]+len(_train)
    nums = sorted(set(_a))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+autoperiod/2 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return list(zip(edges, edges))


def findAnomaliesRange_v2(anomalies, _train):
    '''https://stackoverflow.com/questions/10016802/grouping-a-list-of-integers-with-nearest-values
    '''
    _a = np.where(anomalies)[0]+len(_train)
    _a.sort()
    diff = [_a[i+1]-_a[i] for i in range(len(_a)-1)]
    avg = sum(diff) / len(diff)
    anomalies_group = [[_a[0]]]
    for x in _a[1:]:
        if x - anomalies_group[-1][-1] < avg:
            anomalies_group[-1].append(x)
        else:
            anomalies_group.append([x])
    return anomalies_group

# %% [markdown]
# ### `def plotAnomalies(df_test, anomalies):`

# %%
def plotAnomalies(df: pd.DataFrame,
                  anomalies: np.array,
                  plot_title: str = '',
                  save_folder=''
                  ):
    df_subset = df.iloc[np.where(anomalies)]
    print('len(df)=', len(df))
#     display(df_subset)

    N, M = 25, 6
    fig, ax = plt.subplots(figsize=(N, M))
    ax.set_title(plot_title)
    df.plot(legend=False, ax=ax)
    df_subset.plot(legend=False, ax=ax, color="r")

#     plt.axvline(int(ans["anomaly_start"][j])-100, color="r")
#     plt.axvline(int(ans["anomaly_end"][j])+100, color="r")

    path = f'{save_folder}/{plot_title}.png'
    print('> plotAnomalies(), path=', path)
    plt.savefig(path, facecolor='white', transparent=False)
#     plt.show()
    plt.close()

# %% [markdown]
# # Main

# %% [markdown]
# ## Load data

# %%
path = '../data-sets/KDD-Cup/data/'

loader = DataLoader(path)
loader.loadData()

data_df_list = loader.getDataInDfList()
# Out:
# ..........................................................................................................................................................................................................................................................

# %%
name, data_df = data_df_list[33]

df_train = data_df[data_df['label']=='train']['values'].to_frame()
df_test = data_df[data_df['label']=='test']['values'].to_frame()

display(data_df)

print(name)
print('df_train.shape =', df_train.shape)
print('df_test.shape =', df_test.shape)
# Out:
#          values  label
# 0     76.458008  train
# 1     76.362195  train
# 2     77.233139  train
# 3     77.797305  train
# 4     77.612248  train
# ...         ...    ...
# 7649  45.042070   test
# 7650  46.081865   test
# 7651  45.737770   test
# 7652  45.362732   test
# 7653  45.376655   test
#
# [7654 rows x 2 columns]
# 034_UCR_Anomaly_1500.txt
# df_train.shape = (1500, 1)
# df_test.shape = (6154, 1)

# %% [markdown]
# ## Build, Train and Test Autoencoder for all data

# %%
result_plot_folder = 'results'

if not os.path.exists(result_plot_folder):
    os.makedirs(result_plot_folder)

# %%
for i, (name, data_df) in enumerate(data_df_list[25:]):
    print(f'=== {name} ======================================================')

    # Get data
    _train_df = data_df[data_df['label'] == 'train']['values'].to_frame()
    _test_df = data_df[data_df['label'] == 'test']['values'].to_frame()

    # Normalize data
    _train_df_value = normalize(_train_df)
    _test_df_value = normalize(_test_df, _train_df)

#     # Visualization
#     # Plot of train data (without anomaly)
#     plotTimeSeries(_train_df_value, title=f'{name}, Training ')
#     # Plot of test data (with anomaly)
#     plotTimeSeries(_train_df_value, 100, title=f'{name}, Testing')

    # Find autoperiod
    autoperiod = findAutoPeriod(_train_df['values'])
    autoperiod = int(autoperiod)
#     autoperiod += autoperiod % 2
    print('> autoperiod:', autoperiod)

    # Define Window Size
#     time_steps_ls = [autoperiod-int(autoperiod/2.6), autoperiod+int(autoperiod/2.6), autoperiod]
    time_steps_ls = [autoperiod]

    for time_steps in time_steps_ls:
        try:
            time_steps += time_steps % 2
            print('=== Window Size =', time_steps)

            # Discretize the normalized time series data
            _train_X = createSequences(_train_df_value.values, time_steps)
            _test_X = createSequences(_test_df_value.values, time_steps)
            print("> Training input shape: ", _train_X.shape)

            # Build model
            model_name = f'{name[:-4]}-{time_steps}windowsize-{autoperiod}autoperiod'

            model = buildAutoencoder(shape=(_train_X.shape[1], _train_X.shape[2]))
            # f'{time_steps}windowsize_{autoperiod}autoperiod'
            model._name = model_name
            model.summary()

            # Train model
            batch_size = int(time_steps/5)
            batch_size += batch_size % 2
            print('> batch_size =', batch_size)
            model, history = trainAutoencoder(
                _train_X, model, batch_size=batch_size)

            # Save the trained model
            saveAutoencoder(model, model_name)

            # Test model, detect anomaly
            detector = detectAnomalies(model)
            anomalies = detector.detect(_train_X, _test_X)
            # Save anomalies
            _save = np.where(anomalies)[0]+len(_train_X)
            np.savetxt(f'{result_plot_folder}/anomaly-{model_name}.txt',
                       _save,
                       delimiter=',')

            # Plot Autoencoder result
            detector.plot(save_folder=result_plot_folder,
                          plot_title=f'{model_name}-autoencoder')
            anomalies_ranges = findAnomaliesRange(anomalies, autoperiod, _train_X)

            print("> Reconstruction error threshold: ", detector.threshold)
            print("> Number of anomaly samples: ", np.sum(anomalies))
    #         print("> Indices of anomaly samples: ", np.where(anomalies))
            for _range in anomalies_ranges:
                print("> Indices of anomaly samples: ", np.where(_range))

            # Plot anomaly position
            plotAnomalies(df=_test_df,
                          anomalies=anomalies,
                          plot_title=f'anomaly-{model_name}__{anomalies_ranges}',
                          save_folder=result_plot_folder,
                          )

            keras.backend.clear_session()
            
        except:
            pass
        print()

#         break
#     break
# Out:
# === 026_UCR_Anomaly_1700.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [170.0, 85.0, 89.0, 44.0, 1700.0]
# > autoperiod: 170
# === Window Size = 170
# > Training input shape:  (1531, 170, 1)
# > buildAutoencoder(), shape= (170, 1)
#
# === 027_UCR_Anomaly_1200.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [171.0, 200.0, 92.0, 1200.0, 240.0]
# > autoperiod: 171
# === Window Size = 172
# > Training input shape:  (1029, 172, 1)
# > buildAutoencoder(), shape= (172, 1)
# Model: "027_UCR_Anomaly_1200-172windowsize-171autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 86, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 86, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 43, 8)             520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 86, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 86, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 172, 16)           528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 172, 1)            113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 172, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 28/28 - 1s - loss: 0.3939 - val_loss: 0.0598
# Epoch 2/50
# 28/28 - 0s - loss: 0.0573 - val_loss: 0.0092
# Epoch 3/50
# 28/28 - 0s - loss: 0.0310 - val_loss: 0.0168
# Epoch 4/50
# 28/28 - 0s - loss: 0.0221 - val_loss: 0.0308
# Epoch 5/50
# 28/28 - 0s - loss: 0.0154 - val_loss: 0.0361
# Epoch 6/50
# 28/28 - 1s - loss: 0.0129 - val_loss: 0.0523
# Epoch 7/50
# 28/28 - 0s - loss: 0.0114 - val_loss: 0.0458
# > Saved `models/autoencoder/027_UCR_Anomaly_1200-172windowsize-171autoperiod.h5` !
# > Test input shape:  (6130, 172, 1)
# > Reconstruction error threshold:  0.18593080976093107
# > Number of anomaly samples:  1047
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 6301
# > plotAnomalies(), path= results/anomaly-027_UCR_Anomaly_1200-172windowsize-171autoperiod__[(1451, 1765), (2587, 2874), (3656, 3975), (4752, 4884), (6037, 6170), (7057, 7158)].png
#
# === 028_UCR_Anomaly_1600.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [178.0, 94.0, 200.0, 89.0, 160.0]
# > autoperiod: 178
# === Window Size = 178
# > Training input shape:  (1423, 178, 1)
# > buildAutoencoder(), shape= (178, 1)
#
# === 029_UCR_Anomaly_2300.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [177.0, 192.0, 92.0, 209.0, 1150.0]
# > autoperiod: 177
# === Window Size = 178
# > Training input shape:  (2123, 178, 1)
# > buildAutoencoder(), shape= (178, 1)
#
# === 030_UCR_Anomaly_3000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [188.0, 91.0, 176.0, 200.0, 167.0]
# > autoperiod: 188
# === Window Size = 188
# > Training input shape:  (2813, 188, 1)
# > buildAutoencoder(), shape= (188, 1)
# Model: "030_UCR_Anomaly_3000-188windowsize-188autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 94, 16)            80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 94, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 47, 8)             520
# _________________________________________________________________
# conv1d_transpose_6 (Conv1DTr (None, 94, 8)             264
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 94, 8)             0
# _________________________________________________________________
# conv1d_transpose_7 (Conv1DTr (None, 188, 16)           528
# _________________________________________________________________
# conv1d_transpose_8 (Conv1DTr (None, 188, 1)            113
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 188, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 38
# Epoch 1/50
# 67/67 - 4s - loss: 0.1239 - val_loss: 0.0289
# Epoch 2/50
# 67/67 - 1s - loss: 0.0199 - val_loss: 0.0364
# Epoch 3/50
# 67/67 - 1s - loss: 0.0129 - val_loss: 0.0283
# Epoch 4/50
# 67/67 - 1s - loss: 0.0099 - val_loss: 0.0359
# Epoch 5/50
# 67/67 - 1s - loss: 0.0082 - val_loss: 0.0399
# Epoch 6/50
# 67/67 - 1s - loss: 0.0075 - val_loss: 0.0318
# Epoch 7/50
# 67/67 - 1s - loss: 0.0066 - val_loss: 0.0289
# Epoch 8/50
# 67/67 - 1s - loss: 0.0063 - val_loss: 0.0294
# > Saved `models/autoencoder/030_UCR_Anomaly_3000-188windowsize-188autoperiod.h5` !
# > Test input shape:  (4313, 188, 1)
# > Reconstruction error threshold:  0.1462561068725849
# > Number of anomaly samples:  1
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 4500
# > plotAnomalies(), path= results/anomaly-030_UCR_Anomaly_3000-188windowsize-188autoperiod__[(3925, 3925)].png
#
# === 031_UCR_Anomaly_2700.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [180.0, 93.0, 90.0, 193.0, 169.0]
# > autoperiod: 180
# === Window Size = 180
# > Training input shape:  (2521, 180, 1)
# > buildAutoencoder(), shape= (180, 1)
# Model: "031_UCR_Anomaly_2700-180windowsize-180autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 90, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 90, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 45, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 90, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 90, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 180, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 180, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 180, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 36
# Epoch 1/50
# 63/63 - 2s - loss: 0.2350 - val_loss: 0.0418
# Epoch 2/50
# 63/63 - 1s - loss: 0.0158 - val_loss: 0.0576
# Epoch 3/50
# 63/63 - 1s - loss: 0.0114 - val_loss: 0.0615
# Epoch 4/50
# 63/63 - 2s - loss: 0.0099 - val_loss: 0.0535
# Epoch 5/50
# 63/63 - 1s - loss: 0.0091 - val_loss: 0.0631
# Epoch 6/50
# 63/63 - 1s - loss: 0.0084 - val_loss: 0.0477
# > Saved `models/autoencoder/031_UCR_Anomaly_2700-180windowsize-180autoperiod.h5` !
# > Test input shape:  (4621, 180, 1)
# > Reconstruction error threshold:  0.22568458893991827
# > Number of anomaly samples:  51
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 4800
# > plotAnomalies(), path= results/anomaly-031_UCR_Anomaly_2700-180windowsize-180autoperiod__[(5440, 5490)].png
#
# === 032_UCR_Anomaly_1000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [167.0, 200.0, 91.0, 143.0, 1000.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "032_UCR_Anomaly_1000-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 84, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 84, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 23/23 - 3s - loss: 0.2588 - val_loss: 0.0280
# Epoch 2/50
# 23/23 - 0s - loss: 0.0567 - val_loss: 0.0264
# Epoch 3/50
# 23/23 - 0s - loss: 0.0387 - val_loss: 0.0285
# Epoch 4/50
# 23/23 - 0s - loss: 0.0324 - val_loss: 0.0222
# Epoch 5/50
# 23/23 - 0s - loss: 0.0269 - val_loss: 0.0361
# Epoch 6/50
# 23/23 - 0s - loss: 0.0257 - val_loss: 0.0348
# Epoch 7/50
# 23/23 - 1s - loss: 0.0195 - val_loss: 0.0243
# Epoch 8/50
# 23/23 - 0s - loss: 0.0173 - val_loss: 0.0374
# Epoch 9/50
# 23/23 - 0s - loss: 0.0176 - val_loss: 0.0282
# > Saved `models/autoencoder/032_UCR_Anomaly_1000-168windowsize-167autoperiod.h5` !
# > Test input shape:  (6154, 168, 1)
# > Reconstruction error threshold:  0.17406838930305302
# > Number of anomaly samples:  64
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 6321
# > plotAnomalies(), path= results/anomaly-032_UCR_Anomaly_1000-168windowsize-167autoperiod__[(4550, 4613)].png
#
# === 033_UCR_Anomaly_4000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [174.0, 87.0, 85.0, 43.0, 167.0]
# > autoperiod: 174
# === Window Size = 174
# > Training input shape:  (3827, 174, 1)
# > buildAutoencoder(), shape= (174, 1)
#
# === 034_UCR_Anomaly_1500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [150.0, 75.0, 1500.0, 136.0, 500.0]
# > autoperiod: 150
# === Window Size = 150
# > Training input shape:  (1351, 150, 1)
# > buildAutoencoder(), shape= (150, 1)
#
# === 035_UCR_Anomaly_2500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [167.0, 83.0, 33.0, 42.0, 24.0]
# > autoperiod: 167
# === Window Size = 168
# > Training input shape:  (2333, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "035_UCR_Anomaly_2500-168windowsize-167autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 84, 16)            80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 84, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose_6 (Conv1DTr (None, 84, 8)             264
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_7 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_8 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 62/62 - 1s - loss: 0.1191 - val_loss: 0.0251
# Epoch 2/50
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0215
# Epoch 3/50
# 62/62 - 0s - loss: 0.0156 - val_loss: 0.0211
# Epoch 4/50
# 62/62 - 0s - loss: 0.0117 - val_loss: 0.0203
# Epoch 5/50
# 62/62 - 1s - loss: 0.0097 - val_loss: 0.0170
# Epoch 6/50
# 62/62 - 1s - loss: 0.0085 - val_loss: 0.0184
# Epoch 7/50
# 62/62 - 1s - loss: 0.0072 - val_loss: 0.0165
# Epoch 8/50
# 62/62 - 1s - loss: 0.0068 - val_loss: 0.0223
# Epoch 9/50
# 62/62 - 1s - loss: 0.0063 - val_loss: 0.0155
# Epoch 10/50
# 62/62 - 0s - loss: 0.0059 - val_loss: 0.0173
# Epoch 11/50
# 62/62 - 1s - loss: 0.0057 - val_loss: 0.0119
# Epoch 12/50
# 62/62 - 1s - loss: 0.0055 - val_loss: 0.0116
# Epoch 13/50
# 62/62 - 1s - loss: 0.0054 - val_loss: 0.0156
# Epoch 14/50
# 62/62 - 1s - loss: 0.0051 - val_loss: 0.0185
# Epoch 15/50
# 62/62 - 1s - loss: 0.0052 - val_loss: 0.0260
# Epoch 16/50
# 62/62 - 1s - loss: 0.0050 - val_loss: 0.0207
# Epoch 17/50
# 62/62 - 1s - loss: 0.0047 - val_loss: 0.0193
# > Saved `models/autoencoder/035_UCR_Anomaly_2500-168windowsize-167autoperiod.h5` !
# > Test input shape:  (4834, 168, 1)
# > Reconstruction error threshold:  0.13646093902631132
# > Number of anomaly samples:  0
# len(df)= 5001
# > plotAnomalies(), path= results/anomaly-035_UCR_Anomaly_2500-168windowsize-167autoperiod__[].png
#
# === 036_UCR_Anomaly_4200.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [175.0, 88.0, 1050.0, 1400.0, 89.0]
# > autoperiod: 175
# === Window Size = 176
# > Training input shape:  (4025, 176, 1)
# > buildAutoencoder(), shape= (176, 1)
# Model: "036_UCR_Anomaly_4200-176windowsize-175autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 88, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 88, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 44, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 88, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 88, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 176, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 176, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 176, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 36
# Epoch 1/50
# 101/101 - 2s - loss: 0.1229 - val_loss: 0.0315
# Epoch 2/50
# 101/101 - 3s - loss: 0.0169 - val_loss: 0.0300
# Epoch 3/50
# 101/101 - 2s - loss: 0.0112 - val_loss: 0.0212
# Epoch 4/50
# 101/101 - 1s - loss: 0.0087 - val_loss: 0.0232
# Epoch 5/50
# 101/101 - 2s - loss: 0.0075 - val_loss: 0.0170
# Epoch 6/50
# 101/101 - 2s - loss: 0.0066 - val_loss: 0.0233
# Epoch 7/50
# 101/101 - 2s - loss: 0.0060 - val_loss: 0.0186
# Epoch 8/50
# 101/101 - 1s - loss: 0.0056 - val_loss: 0.0143
# Epoch 9/50
# 101/101 - 1s - loss: 0.0054 - val_loss: 0.0233
# Epoch 10/50
# 101/101 - 1s - loss: 0.0052 - val_loss: 0.0203
# Epoch 11/50
# 101/101 - 1s - loss: 0.0047 - val_loss: 0.0162
# Epoch 12/50
# 101/101 - 1s - loss: 0.0045 - val_loss: 0.0196
# Epoch 13/50
# 101/101 - 1s - loss: 0.0044 - val_loss: 0.0194
# > Saved `models/autoencoder/036_UCR_Anomaly_4200-176windowsize-175autoperiod.h5` !
# > Test input shape:  (3126, 176, 1)
# > Reconstruction error threshold:  0.16033809872148994
# > Number of anomaly samples:  0
# len(df)= 3301
# > plotAnomalies(), path= results/anomaly-036_UCR_Anomaly_4200-176windowsize-175autoperiod__[].png
#
# === 037_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [17.0, 34.0, 17.0, 35.0, 17.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (4965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "037_UCR_Anomaly_5000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 559/559 - 5s - loss: 0.1139 - val_loss: 0.0954
# Epoch 2/50
# 559/559 - 2s - loss: 0.0619 - val_loss: 0.0991
# Epoch 3/50
# 559/559 - 2s - loss: 0.0543 - val_loss: 0.0858
# Epoch 4/50
# 559/559 - 2s - loss: 0.0521 - val_loss: 0.0631
# Epoch 5/50
# 559/559 - 1s - loss: 0.0517 - val_loss: 0.0782
# Epoch 6/50
# 559/559 - 2s - loss: 0.0487 - val_loss: 0.0421
# Epoch 7/50
# 559/559 - 2s - loss: 0.0471 - val_loss: 0.0682
# Epoch 8/50
# 559/559 - 2s - loss: 0.0450 - val_loss: 0.0546
# Epoch 9/50
# 559/559 - 2s - loss: 0.0444 - val_loss: 0.0675
# Epoch 10/50
# 559/559 - 2s - loss: 0.0419 - val_loss: 0.0828
# Epoch 11/50
# 559/559 - 2s - loss: 0.0427 - val_loss: 0.0632
# > Saved `models/autoencoder/037_UCR_Anomaly_5000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (24966, 36, 1)
# > Reconstruction error threshold:  0.35577722237502973
# > Number of anomaly samples:  55
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 25001
# > plotAnomalies(), path= results/anomaly-037_UCR_Anomaly_5000-36windowsize-35autoperiod__[(17155, 17209)].png
#
# === 038_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [17.0, 34.0, 17.0, 35.0, 17.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (4965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "038_UCR_Anomaly_5000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 559/559 - 8s - loss: 0.1044 - val_loss: 0.0813
# Epoch 2/50
# 559/559 - 1s - loss: 0.0571 - val_loss: 0.1014
# Epoch 3/50
# 559/559 - 2s - loss: 0.0508 - val_loss: 0.1014
# Epoch 4/50
# 559/559 - 1s - loss: 0.0488 - val_loss: 0.0852
# Epoch 5/50
# 559/559 - 1s - loss: 0.0459 - val_loss: 0.1026
# Epoch 6/50
# 559/559 - 2s - loss: 0.0448 - val_loss: 0.0978
# > Saved `models/autoencoder/038_UCR_Anomaly_5000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (24915, 36, 1)
# > Reconstruction error threshold:  0.3419141713937248
# > Number of anomaly samples:  21
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 24950
# > plotAnomalies(), path= results/anomaly-038_UCR_Anomaly_5000-36windowsize-35autoperiod__[(12775, 12779), (23940, 23942), (29732, 29763)].png
#
# === 039_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [34.0, 17.0, 17.0, 35.0, 17.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (4965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "039_UCR_Anomaly_5000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 559/559 - 4s - loss: 0.0982 - val_loss: 0.0694
# Epoch 2/50
# 559/559 - 2s - loss: 0.0499 - val_loss: 0.0528
# Epoch 3/50
# 559/559 - 1s - loss: 0.0417 - val_loss: 0.0566
# Epoch 4/50
# 559/559 - 1s - loss: 0.0368 - val_loss: 0.0652
# Epoch 5/50
# 559/559 - 1s - loss: 0.0351 - val_loss: 0.0778
# Epoch 6/50
# 559/559 - 1s - loss: 0.0338 - val_loss: 0.0941
# Epoch 7/50
# 559/559 - 1s - loss: 0.0341 - val_loss: 0.1163
# > Saved `models/autoencoder/039_UCR_Anomaly_5000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (24915, 36, 1)
# > Reconstruction error threshold:  0.42967171484816746
# > Number of anomaly samples:  72
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 24950
# > plotAnomalies(), path= results/anomaly-039_UCR_Anomaly_5000-36windowsize-35autoperiod__[(7401, 7402), (16324, 16380), (18459, 18463), (18723, 18723), (20517, 20519), (20683, 20683), (20713, 20713), (21191, 21191), (21380, 21380), (21410, 21413)].png
#
# === 040_UCR_Anomaly_6000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [35.0, 17.0, 17.0, 17.0, 11.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (5965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "040_UCR_Anomaly_6000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 671/671 - 2s - loss: 0.0907 - val_loss: 0.0716
# Epoch 2/50
# 671/671 - 1s - loss: 0.0523 - val_loss: 0.0723
# Epoch 3/50
# 671/671 - 2s - loss: 0.0483 - val_loss: 0.0777
# Epoch 4/50
# 671/671 - 2s - loss: 0.0456 - val_loss: 0.0689
# Epoch 5/50
# 671/671 - 1s - loss: 0.0414 - val_loss: 0.0626
# Epoch 6/50
# 671/671 - 1s - loss: 0.0375 - val_loss: 0.0501
# Epoch 7/50
# 671/671 - 1s - loss: 0.0374 - val_loss: 0.0694
# Epoch 8/50
# 671/671 - 1s - loss: 0.0384 - val_loss: 0.0857
# Epoch 9/50
# 671/671 - 1s - loss: 0.0372 - val_loss: 0.0709
# Epoch 10/50
# 671/671 - 1s - loss: 0.0352 - val_loss: 0.0828
# Epoch 11/50
# 671/671 - 1s - loss: 0.0345 - val_loss: 0.0816
# > Saved `models/autoencoder/040_UCR_Anomaly_6000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (24031, 36, 1)
# > Reconstruction error threshold:  0.3389378922774018
# > Number of anomaly samples:  54
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 24066
# > plotAnomalies(), path= results/anomaly-040_UCR_Anomaly_6000-36windowsize-35autoperiod__[(8124, 8124), (15821, 15825), (16431, 16435), (16952, 16952), (17513, 17517), (17576, 17592), (18301, 18301), (18390, 18394), (18577, 18578), (19614, 19614), (20237, 20242), (20300, 20300), (20465, 20465), (20631, 20636), (21527, 21527)].png
#
# === 041_UCR_Anomaly_7000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [18.0, 17.0, 35.0, 35.0, 34.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (6965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "041_UCR_Anomaly_7000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 18, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 18, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 784/784 - 3s - loss: 0.0954 - val_loss: 0.0465
# Epoch 2/50
# 784/784 - 2s - loss: 0.0498 - val_loss: 0.0596
# Epoch 3/50
# 784/784 - 3s - loss: 0.0451 - val_loss: 0.0485
# Epoch 4/50
# 784/784 - 2s - loss: 0.0391 - val_loss: 0.0372
# Epoch 5/50
# 784/784 - 2s - loss: 0.0363 - val_loss: 0.0497
# Epoch 6/50
# 784/784 - 2s - loss: 0.0347 - val_loss: 0.0627
# Epoch 7/50
# 784/784 - 4s - loss: 0.0343 - val_loss: 0.0487
# Epoch 8/50
# 784/784 - 4s - loss: 0.0327 - val_loss: 0.0453
# Epoch 9/50
# 784/784 - 5s - loss: 0.0323 - val_loss: 0.0646
# > Saved `models/autoencoder/041_UCR_Anomaly_7000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (22791, 36, 1)
# > Reconstruction error threshold:  0.3238502760257282
# > Number of anomaly samples:  39
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 22826
# > plotAnomalies(), path= results/anomaly-041_UCR_Anomaly_7000-36windowsize-35autoperiod__[(17336, 17371), (19648, 19657), (21282, 21287)].png
#
# === 042_UCR_Anomaly_7000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [18.0, 17.0, 35.0, 35.0, 12.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (6965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "042_UCR_Anomaly_7000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 784/784 - 8s - loss: 0.0980 - val_loss: 0.0597
# Epoch 2/50
# 784/784 - 4s - loss: 0.0538 - val_loss: 0.0633
# Epoch 3/50
# 784/784 - 4s - loss: 0.0496 - val_loss: 0.0752
# Epoch 4/50
# 784/784 - 4s - loss: 0.0474 - val_loss: 0.0836
# Epoch 5/50
# 784/784 - 4s - loss: 0.0445 - val_loss: 0.0609
# Epoch 6/50
# 784/784 - 4s - loss: 0.0420 - val_loss: 0.0423
# Epoch 7/50
# 784/784 - 6s - loss: 0.0419 - val_loss: 0.0587
# Epoch 8/50
# 784/784 - 8s - loss: 0.0413 - val_loss: 0.0478
# Epoch 9/50
# 784/784 - 5s - loss: 0.0381 - val_loss: 0.1017
# Epoch 10/50
# 784/784 - 3s - loss: 0.0378 - val_loss: 0.0754
# Epoch 11/50
# 784/784 - 2s - loss: 0.0384 - val_loss: 0.0638
# > Saved `models/autoencoder/042_UCR_Anomaly_7000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (22824, 36, 1)
# > Reconstruction error threshold:  0.31504504085627516
# > Number of anomaly samples:  3
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 22859
# > plotAnomalies(), path= results/anomaly-042_UCR_Anomaly_7000-36windowsize-35autoperiod__[(16356, 16356), (20424, 20428)].png
#
# === 043_UCR_Anomaly_10000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [10000.0, 5000.0, 3333.0, 2500.0, 1667.0]
# > autoperiod: 10000
# === Window Size = 10000
# > Training input shape:  (1, 10000, 1)
# > buildAutoencoder(), shape= (10000, 1)
# Model: "043_UCR_Anomaly_10000-10000windowsize-10000autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 5000, 16)          80
# _________________________________________________________________
# dropout (Dropout)            (None, 5000, 16)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2500, 8)           520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 5000, 8)           264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5000, 8)           0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 10000, 16)         528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 10000, 1)          113
# _________________________________________________________________
# reshape (Reshape)            (None, 10000, 1)          0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 2000
#
# === 044_UCR_Anomaly_9000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 12.0, 9000.0, 167.0, 84.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (8977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "044_UCR_Anomaly_9000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 12, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 12, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 2020/2020 - 11s - loss: 0.0543 - val_loss: 0.0387
# Epoch 2/50
# 2020/2020 - 5s - loss: 0.0302 - val_loss: 0.0935
# Epoch 3/50
# 2020/2020 - 5s - loss: 0.0292 - val_loss: 0.0901
# Epoch 4/50
# 2020/2020 - 4s - loss: 0.0274 - val_loss: 0.0703
# Epoch 5/50
# 2020/2020 - 6s - loss: 0.0279 - val_loss: 0.0708
# Epoch 6/50
# 2020/2020 - 4s - loss: 0.0277 - val_loss: 0.0770
# > Saved `models/autoencoder/044_UCR_Anomaly_9000-24windowsize-24autoperiod.h5` !
# > Test input shape:  (20908, 24, 1)
# > Reconstruction error threshold:  0.7222346182528879
# > Number of anomaly samples:  17
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 20931
# > plotAnomalies(), path= results/anomaly-044_UCR_Anomaly_9000-24windowsize-24autoperiod__[(14082, 14098)].png
#
# === 045_UCR_Anomaly_14000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 7000.0, 169.0, 12.0, 12.0]
# > autoperiod: 169
# === Window Size = 170
# > Training input shape:  (13831, 170, 1)
# > buildAutoencoder(), shape= (170, 1)
#
# === 046_UCR_Anomaly_16000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 8000.0, 12.0, 168.0, 24.0]
# > autoperiod: 168
# === Window Size = 168
# > Training input shape:  (15833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "046_UCR_Anomaly_16000-168windowsize-168autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 84, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 84, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 84, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 420/420 - 6s - loss: 0.0640 - val_loss: 0.0384
# Epoch 2/50
# 420/420 - 3s - loss: 0.0234 - val_loss: 0.0519
# Epoch 3/50
# 420/420 - 3s - loss: 0.0192 - val_loss: 0.0410
# Epoch 4/50
# 420/420 - 3s - loss: 0.0170 - val_loss: 0.0514
# Epoch 5/50
# 420/420 - 4s - loss: 0.0158 - val_loss: 0.0747
# Epoch 6/50
# 420/420 - 3s - loss: 0.0150 - val_loss: 0.0830
# > Saved `models/autoencoder/046_UCR_Anomaly_16000-168windowsize-168autoperiod.h5` !
# > Test input shape:  (13764, 168, 1)
# > Reconstruction error threshold:  0.5212036172368835
# > Number of anomaly samples:  40
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 13931
# > plotAnomalies(), path= results/anomaly-046_UCR_Anomaly_16000-168windowsize-168autoperiod__[(22781, 22849)].png
#
# === 047_UCR_Anomaly_18000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 9000.0, 12.0, 168.0, 84.0]
# > autoperiod: 168
# === Window Size = 168
# > Training input shape:  (17833, 168, 1)
# > buildAutoencoder(), shape= (168, 1)
# Model: "047_UCR_Anomaly_18000-168windowsize-168autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 84, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 42, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 84, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 168, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 168, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 168, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 34
# Epoch 1/50
# 473/473 - 6s - loss: 0.0621 - val_loss: 0.0314
# Epoch 2/50
# 473/473 - 4s - loss: 0.0217 - val_loss: 0.0488
# Epoch 3/50
# 473/473 - 4s - loss: 0.0187 - val_loss: 0.0750
# Epoch 4/50
# 473/473 - 4s - loss: 0.0171 - val_loss: 0.0660
# Epoch 5/50
# 473/473 - 4s - loss: 0.0159 - val_loss: 0.0446
# Epoch 6/50
# 473/473 - 4s - loss: 0.0154 - val_loss: 0.0979
# > Saved `models/autoencoder/047_UCR_Anomaly_18000-168windowsize-168autoperiod.h5` !
# > Test input shape:  (11764, 168, 1)
# > Reconstruction error threshold:  0.3607685253305731
# > Number of anomaly samples:  1
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 11931
# > plotAnomalies(), path= results/anomaly-047_UCR_Anomaly_18000-168windowsize-168autoperiod__[(25701, 25701)].png
#
# === 048_UCR_Anomaly_3500.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [97.0, 49.0, 100.0, 33.0, 95.0]
# > autoperiod: 100
# === Window Size = 100
# > Training input shape:  (3401, 100, 1)
# > buildAutoencoder(), shape= (100, 1)
# Model: "048_UCR_Anomaly_3500-100windowsize-100autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 50, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 25, 8)             520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 50, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 100, 16)           528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 100, 1)            113
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 1)            0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 20
# Epoch 1/50
# 153/153 - 4s - loss: 0.0878 - val_loss: 0.0394
# Epoch 2/50
# 153/153 - 1s - loss: 0.0176 - val_loss: 0.0389
# Epoch 3/50
# 153/153 - 1s - loss: 0.0130 - val_loss: 0.0363
# Epoch 4/50
# 153/153 - 1s - loss: 0.0115 - val_loss: 0.0241
# Epoch 5/50
# 153/153 - 1s - loss: 0.0092 - val_loss: 0.0268
# Epoch 6/50
# 153/153 - 1s - loss: 0.0084 - val_loss: 0.0459
# Epoch 7/50
# 153/153 - 1s - loss: 0.0076 - val_loss: 0.0191
# Epoch 8/50
# 153/153 - 1s - loss: 0.0072 - val_loss: 0.0273
# Epoch 9/50
# 153/153 - 1s - loss: 0.0067 - val_loss: 0.0291
# Epoch 10/50
# 153/153 - 1s - loss: 0.0069 - val_loss: 0.0213
# Epoch 11/50
# 153/153 - 1s - loss: 0.0065 - val_loss: 0.0186
# Epoch 12/50
# 153/153 - 1s - loss: 0.0059 - val_loss: 0.0273
# ...
# === 147_UCR_Anomaly_5000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [17.0, 34.0, 17.0, 35.0, 17.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (4965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "147_UCR_Anomaly_5000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 18, 16)            80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 18, 16)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose_6 (Conv1DTr (None, 18, 8)             264
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_7 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_8 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 559/559 - 4s - loss: 0.1130 - val_loss: 0.0835
# Epoch 2/50
# 559/559 - 2s - loss: 0.0583 - val_loss: 0.0903
# Epoch 3/50
# 559/559 - 2s - loss: 0.0516 - val_loss: 0.0743
# Epoch 4/50
# 559/559 - 1s - loss: 0.0489 - val_loss: 0.0637
# Epoch 5/50
# 559/559 - 2s - loss: 0.0448 - val_loss: 0.0461
# Epoch 6/50
# 559/559 - 1s - loss: 0.0429 - val_loss: 0.0460
# Epoch 7/50
# 559/559 - 1s - loss: 0.0412 - val_loss: 0.0628
# Epoch 8/50
# 559/559 - 2s - loss: 0.0390 - val_loss: 0.0749
# Epoch 9/50
# 559/559 - 2s - loss: 0.0375 - val_loss: 0.0609
# Epoch 10/50
# 559/559 - 2s - loss: 0.0367 - val_loss: 0.0771
# Epoch 11/50
# 559/559 - 2s - loss: 0.0358 - val_loss: 0.0620
# > Saved `models/autoencoder/147_UCR_Anomaly_5000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (24915, 36, 1)
# > Reconstruction error threshold:  0.2812815722709726
# > Number of anomaly samples:  68
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 24950
# > plotAnomalies(), path= results/anomaly-147_UCR_Anomaly_5000-36windowsize-35autoperiod__[(5042, 5046), (5214, 5215), (16321, 16380), (20517, 20517), (24334, 24354)].png
#
# === 148_UCR_Anomaly_6000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [35.0, 17.0, 17.0, 17.0, 34.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (5965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "148_UCR_Anomaly_6000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 671/671 - 3s - loss: 0.1034 - val_loss: 0.0521
# Epoch 2/50
# 671/671 - 2s - loss: 0.0536 - val_loss: 0.0454
# Epoch 3/50
# 671/671 - 2s - loss: 0.0464 - val_loss: 0.0417
# Epoch 4/50
# 671/671 - 2s - loss: 0.0398 - val_loss: 0.0324
# Epoch 5/50
# 671/671 - 2s - loss: 0.0375 - val_loss: 0.0454
# Epoch 6/50
# 671/671 - 2s - loss: 0.0365 - val_loss: 0.0260
# Epoch 7/50
# 671/671 - 2s - loss: 0.0356 - val_loss: 0.0424
# Epoch 8/50
# 671/671 - 2s - loss: 0.0350 - val_loss: 0.0375
# Epoch 9/50
# 671/671 - 2s - loss: 0.0335 - val_loss: 0.0462
# Epoch 10/50
# 671/671 - 2s - loss: 0.0334 - val_loss: 0.0349
# Epoch 11/50
# 671/671 - 2s - loss: 0.0332 - val_loss: 0.0281
# > Saved `models/autoencoder/148_UCR_Anomaly_6000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (24031, 36, 1)
# > Reconstruction error threshold:  0.21093354944170614
# > Number of anomaly samples:  2
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 24066
# > plotAnomalies(), path= results/anomaly-148_UCR_Anomaly_6000-36windowsize-35autoperiod__[(18577, 18578)].png
#
# === 149_UCR_Anomaly_7000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [18.0, 17.0, 35.0, 35.0, 12.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (6965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "149_UCR_Anomaly_7000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 784/784 - 4s - loss: 0.0959 - val_loss: 0.0603
# Epoch 2/50
# 784/784 - 2s - loss: 0.0536 - val_loss: 0.0581
# Epoch 3/50
# 784/784 - 3s - loss: 0.0477 - val_loss: 0.0416
# Epoch 4/50
# 784/784 - 3s - loss: 0.0433 - val_loss: 0.0375
# Epoch 5/50
# 784/784 - 3s - loss: 0.0412 - val_loss: 0.0309
# Epoch 6/50
# 784/784 - 3s - loss: 0.0397 - val_loss: 0.0311
# Epoch 7/50
# 784/784 - 2s - loss: 0.0374 - val_loss: 0.0495
# Epoch 8/50
# 784/784 - 3s - loss: 0.0377 - val_loss: 0.0288
# Epoch 9/50
# 784/784 - 2s - loss: 0.0370 - val_loss: 0.0576
# Epoch 10/50
# 784/784 - 2s - loss: 0.0358 - val_loss: 0.0532
# Epoch 11/50
# 784/784 - 2s - loss: 0.0347 - val_loss: 0.0514
# Epoch 12/50
# 784/784 - 2s - loss: 0.0349 - val_loss: 0.0698
# Epoch 13/50
# 784/784 - 2s - loss: 0.0343 - val_loss: 0.0964
# > Saved `models/autoencoder/149_UCR_Anomaly_7000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (22791, 36, 1)
# > Reconstruction error threshold:  0.3753760251951601
# > Number of anomaly samples:  26
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# > Indices of anomaly samples:  (array([0, 1]),)
# len(df)= 22826
# > plotAnomalies(), path= results/anomaly-149_UCR_Anomaly_7000-36windowsize-35autoperiod__[(7345, 7347), (16365, 16365), (16393, 16393), (18336, 18340), (19999, 20031), (20059, 20063), (20393, 20395), (21258, 21266), (21286, 21289)].png
#
# === 150_UCR_Anomaly_7000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [18.0, 17.0, 35.0, 35.0, 34.0]
# > autoperiod: 35
# === Window Size = 36
# > Training input shape:  (6965, 36, 1)
# > buildAutoencoder(), shape= (36, 1)
# Model: "150_UCR_Anomaly_7000-36windowsize-35autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 16)            80
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 8)              520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 18, 8)             264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 8)             0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 36, 16)            528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 36, 1)             113
# _________________________________________________________________
# reshape (Reshape)            (None, 36, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 8
# Epoch 1/50
# 784/784 - 5s - loss: 0.0885 - val_loss: 0.0644
# Epoch 2/50
# 784/784 - 3s - loss: 0.0502 - val_loss: 0.0870
# Epoch 3/50
# 784/784 - 3s - loss: 0.0447 - val_loss: 0.0665
# Epoch 4/50
# 784/784 - 3s - loss: 0.0405 - val_loss: 0.0664
# Epoch 5/50
# 784/784 - 3s - loss: 0.0399 - val_loss: 0.0779
# Epoch 6/50
# 784/784 - 3s - loss: 0.0360 - val_loss: 0.0585
# Epoch 7/50
# 784/784 - 3s - loss: 0.0343 - val_loss: 0.0526
# Epoch 8/50
# 784/784 - 3s - loss: 0.0327 - val_loss: 0.0457
# Epoch 9/50
# 784/784 - 3s - loss: 0.0309 - val_loss: 0.0562
# Epoch 10/50
# 784/784 - 2s - loss: 0.0316 - val_loss: 0.0610
# Epoch 11/50
# 784/784 - 2s - loss: 0.0300 - val_loss: 0.1032
# Epoch 12/50
# 784/784 - 2s - loss: 0.0311 - val_loss: 0.0741
# Epoch 13/50
# 784/784 - 2s - loss: 0.0305 - val_loss: 0.0598
# > Saved `models/autoencoder/150_UCR_Anomaly_7000-36windowsize-35autoperiod.h5` !
# > Test input shape:  (22824, 36, 1)
# > Reconstruction error threshold:  0.36445965126061175
# > Number of anomaly samples:  0
# len(df)= 22859
# > plotAnomalies(), path= results/anomaly-150_UCR_Anomaly_7000-36windowsize-35autoperiod__[].png
#
# === 151_UCR_Anomaly_10000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [10000.0, 5000.0, 3333.0, 2500.0, 1667.0]
# > autoperiod: 10000
# === Window Size = 10000
# > Training input shape:  (1, 10000, 1)
# > buildAutoencoder(), shape= (10000, 1)
# Model: "151_UCR_Anomaly_10000-10000windowsize-10000autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 5000, 16)          80
# _________________________________________________________________
# dropout (Dropout)            (None, 5000, 16)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2500, 8)           520
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 5000, 8)           264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5000, 8)           0
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 10000, 16)         528
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 10000, 1)          113
# _________________________________________________________________
# reshape (Reshape)            (None, 10000, 1)          0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 2000
#
# === 152_UCR_Anomaly_9000.txt ======================================================
# > Normalizing by same `mean` `std`.
# > Normalizing by other `mean` `std`.
# [24.0, 9000.0, 12.0, 167.0, 84.0]
# > autoperiod: 24
# === Window Size = 24
# > Training input shape:  (8977, 24, 1)
# > buildAutoencoder(), shape= (24, 1)
# Model: "152_UCR_Anomaly_9000-24windowsize-24autoperiod"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 12, 16)            80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 6, 8)              520
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 12, 8)             264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 8)             0
# _________________________________________________________________
# conv1d_transpose_4 (Conv1DTr (None, 24, 16)            528
# _________________________________________________________________
# conv1d_transpose_5 (Conv1DTr (None, 24, 1)             113
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 24, 1)             0
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# > batch_size = 4
# Epoch 1/50
# 2020/2020 - 15s - loss: 0.0671 - val_loss: 0.0328
# Epoch 2/50
# 2020/2020 - 10s - loss: 0.0396 - val_loss: 0.0409
# Epoch 3/50
# 2020/2020 - 7s - loss: 0.0375 - val_loss: 0.0359
# Epoch 4/50
# 2020/2020 - 4s - loss: 0.0363 - val_loss: 0.0346
# Epoch 5/50
# 2020/2020 - 8s - loss: 0.0347 - val_loss: 0.0537
# Epoch 6/50
# 2020/2020 - 8s - loss: 0.0331 - val_loss: 0.0361

# %%
# model = keras.models.load_model('models/autoencoder/001_UCR_Anomaly_35000-132_windowsize-212_autoperiod.h5')

# detector = detectAnomalies(model)
# anomalies = detector.detect(_train_X, _test_X)
# detector.plot(save_folder = result_plot_folder,
#               plot_title = model_name)

# %%
# anomalies_ranges = findAnomaliesRange(anomalies, autoperiod, _train_X)
# anomalies_ranges
# [b-a for a,b in anomalies_ranges]

# %%
# _save = np.where(anomalies)[0]+len(_train_X)

# print(_save)
# np.savetxt('test.out', _save, delimiter=',')   # X is an array

# %%
# np.loadtxt("test.out")

# %%
keras.backend.clear_session()
del model

# %%
keras.__version__
